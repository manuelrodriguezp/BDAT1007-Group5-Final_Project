# %%
# Web scrapping from reviews of movies from Rotten Tomatoes
# Movie: Hillbilly Elegy
# Import libraries
import requests
from bs4 import BeautifulSoup
import re

#SA: vadar sentiment analyzer library
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

#SA: sentiment analyzer instance
analyser = SentimentIntensityAnalyzer()

# Collect first page of artists’ list (Collecting and Parsing data)
page = requests.get('https://www.rottentomatoes.com/m/hillbilly_elegy/reviews?type=top_critics&sort=')

# Create a BeautifulSoup object
soup = BeautifulSoup(page.text, 'html.parser')

# Pull all text from the review 
hillbily_elegy = soup.find(class_='review_table')

# Remove tag <span>
for match in hillbily_elegy.findAll('span'):
    match.unwrap()

# Pull text from all instances of <h6> tag within BodyText div
hillbilly_review = hillbily_elegy.find_all(class_='the_review')

# Pull text from all instances of 'cast' tag within BodyText div
hillbilly_date = hillbily_elegy.find_all(class_='review-date subtle small')

# Pull text from all instances of 'genre' tag within BodyText div
hillbilly_critic = hillbily_elegy.find_all(class_='unstyled bold articleLink')

comments = []
for review in hillbilly_review:
    rev = review.contents[0]
    rev = re.sub('\r\n', '', rev)
    patt = re.compile('(\s*) The | in | of | and | a | that | to | is | for | on |&mdash; | with | but | was | are | as |the | this | you | his | they | They | has | A | at | he | But | a | the | of |and | it | it\'s | an |,(\s*)')
    rev = patt.sub(' ', rev)
    comments.append(rev)

dates = []
for date in hillbilly_date:
    dat = date.contents[0]
    dat = re.sub('\r\n', '', dat)
    dates.append(dat)

critics = []
for critic in hillbilly_critic:
    crit = critic.contents[0]
    crit = re.sub('\r\n', '', crit)
    critics.append(crit)

# Collect first page of artists’ list (Collecting and Parsing data)
page = requests.get('https://www.rottentomatoes.com/m/hillbilly_elegy/reviews?type=top_critics&sort=&page=2')

# Create a BeautifulSoup object
soup = BeautifulSoup(page.text, 'html.parser')

# Pull all text from the review 
hillbily_elegy = soup.find(class_='review_table')

# Remove tag <span>
for match in hillbily_elegy.findAll('span'):
    match.unwrap()

# Pull text from all instances of <h6> tag within BodyText div
hillbilly_review = hillbily_elegy.find_all(class_='the_review')

# Pull text from all instances of 'cast' tag within BodyText div
hillbilly_date = hillbily_elegy.find_all(class_='review-date subtle small')

# Pull text from all instances of 'genre' tag within BodyText div
hillbilly_critic = hillbily_elegy.find_all(class_='unstyled bold articleLink')

for review in hillbilly_review:
    rev = review.contents[0]
    rev = re.sub('\r\n', '', rev)
    patt = re.compile('(\s*) The | in | of | and | a | that | to | is | for | on |&mdash; | with | but | was | are | as |the | this | you | his | they | They | has | A | at | he | But | a | the | of |and | it | it\'s | an |,(\s*)')
    rev = patt.sub(' ', rev)
    comments.append(rev)
    
for date in hillbilly_date:
    dat = date.contents[0]
    dat = re.sub('\r\n', '', dat)
    dates.append(dat)

for critic in hillbilly_critic:
    crit = critic.contents[0]
    crit = re.sub('\r\n', '', crit)
    critics.append(crit)

# Collect first page of artists’ list (Collecting and Parsing data)
page = requests.get('https://www.rottentomatoes.com/m/hillbilly_elegy/reviews?type=top_critics&sort=&page=3')

# Create a BeautifulSoup object
soup = BeautifulSoup(page.text, 'html.parser')

# Pull all text from the review 
hillbily_elegy = soup.find(class_='review_table')

# Remove tag <span>
for match in hillbily_elegy.findAll('span'):
    match.unwrap()

# Pull text from all instances of <h6> tag within BodyText div
hillbilly_review = hillbily_elegy.find_all(class_='the_review')

# Pull text from all instances of 'cast' tag within BodyText div
hillbilly_date = hillbily_elegy.find_all(class_='review-date subtle small')

# Pull text from all instances of 'genre' tag within BodyText div
hillbilly_critic = hillbily_elegy.find_all(class_='unstyled bold articleLink')

for review in hillbilly_review:
    rev = review.contents[0]
    rev = re.sub('\r\n', '', rev)
    patt = re.compile('(\s*) The | in | of | and | a | that | to | is | for | on |&mdash; | with | but | was | are | as |the | this | you | his | they | They | has | A | at | he | But | a | the | of |and | it | it\'s | an |,(\s*)')
    rev = patt.sub(' ', rev)
    comments.append(rev)

for date in hillbilly_date:
    dat = date.contents[0]
    dat = re.sub('\r\n', '', dat)
    dates.append(dat)

for critic in hillbilly_critic:
    crit = critic.contents[0]
    crit = re.sub('\r\n', '', crit)
    critics.append(crit)

reviews_hillbilly_elegy = []
for i in range (0,57):
    record = []
    record.append('Hillbilly Elegy')
    record.append(critics[i])
    record.append(dates[i])
    record.append(comments[i])
    
    #SA: appending compound scores and categories
    sentiment_rev = analyser.polarity_scores(comments[i])
    record.append(sentiment_rev['compound'])

    #SA: Classificatin of compound score
    if sentiment_rev['compound'] >= 0.05:
        record.append('Positive')
    elif sentiment_rev['compound'] <= - 0.05:
        record.append('Negative')
    else:
        record.append('Neutral')
           
    reviews_hillbilly_elegy.append(record)
reviews_hillbilly_elegy
# Out:
# [['Hillbilly Elegy',
#   'Wenlei Ma',
#   '                December 8, 2020            ',
#   '                    Adams Close deserved better than relentlessly gloomy often trite movie. We all did.                ',
#   0.128,
#   'Positive'],
#  ['Hillbilly Elegy',
#   'Sara Stewart',
#   '                December 4, 2020            ',
#   "                    There's only vague message about bootstraps personal responsibility  a whole lot bad wigs.                ",
#   -0.5994,
#   'Negative'],
#  ['Hillbilly Elegy',
#   'Jordan Hoffman',
#   '                December 4, 2020            ',
#   '                    Hillbilly Elegy its Oscar dreams all sizzle no steak.                ',
#   0.128,
#   'Positive'],
#  ['Hillbilly Elegy',
#   'David Sims',
#   '                December 4, 2020            ',
#   '                    Hillbilly Elegy an Oscar-friendly narrative personal triumph  face great hardship a movie designed end an uplifting epigraph; is also one  worst movies  year.                ',
#   0.2023,
#   'Positive'],
#  ['Hillbilly Elegy',
#   'Adam Nayman',
#   '                December 2, 2020            ',
#   '                    Hillbilly Elegy communicates precious little about culture depicts - exploits - Oscar-baiting aspirations.                ',
#   0.3182,
#   'Positive'],
#  ['Hillbilly Elegy',
#   'Esther Zuckerman',
#   '                December 1, 2020            ',
#   '                    For all overbearing sound fury  two lead performances for all purported gravitas in end just feels pointless a poverty porn portrayal  lives intends honor.                ',
#   -0.5859,
#   'Negative'],
#  ['Hillbilly Elegy',
#   'Simran Hans',
#   '                November 30, 2020            ',
#   "                    It's prestige slog full flat sneering caricatures.                ",
#   0.0,
#   'Neutral'],
#  ['Hillbilly Elegy',
#   'Richard Brody',
#   '                November 28, 2020            ',
#   "                    With soupy impersonal manipulations memory experience void  burrs attach them  world large Howard whether intentionally or not has made libertarian's fantasy.                ",
#   -0.3182,
#   'Negative'],
#  ['Hillbilly Elegy',
#   'Darren Franich',
#   '                November 28, 2020            ',
#   "                    Howard thinks he's making inspirational tale. He doesn't realize an American horror story.                ",
#   -0.1027,
#   'Negative'],
#  ['Hillbilly Elegy',
#   "Charlotte O'Sullivan",
#   '                November 26, 2020            ',
#   "                    Suffice say unless you're silly billy you'll see through pantomime. This fight ain't fair; been rigged.                ",
#   -0.4122,
#   'Negative'],
#  ['Hillbilly Elegy',
#   'Angie Han',
#   '                November 25, 2020            ',
#   '                    Hillbilly Elegy sounds folksy but conveys nothing. It\'s " neutral" movies taking up space no end all.                ',
#   -0.4215,
#   'Negative'],
#  ['Hillbilly Elegy',
#   'Alison Willmore',
#   '                November 24, 2020            ',
#   " film like package assorted chicken parts can't be assembled back into something approximating shape an actual animal - there's way too much some stuff while certain essentials missing entirely.                ",
#   0.34,
#   'Positive'],
#  ['Hillbilly Elegy',
#   'James Berardinelli',
#   '                November 24, 2020            ',
#   "                    Here's rare example a Netflix prestige film neither runs too long nor overstays its welcome.                ",
#   -0.357,
#   'Negative'],
#  ['Hillbilly Elegy',
#   'Brian Lowry',
#   '                November 24, 2020            ',
#   '                    These would theoretically be juicy roles Adams Close but even those stars letting loose  conversations about broader cultural economic challenges  book triggered get obscured by what feels more like Lifetime movie.                ',
#   0.2936,
#   'Positive'],
#  ['Hillbilly Elegy',
#   'Stephanie Zacharek',
#   '                November 24, 2020            ',
#   "                    Hillbilly Elegy isn't terrible  trailers make look but an enterprise just all-around sad a movie courts sympathy its characters yet ends up only a requiem itself.                ",
#   -0.0317,
#   'Neutral'],
#  ['Hillbilly Elegy',
#   'A.O. Scott',
#   '                November 24, 2020            ',
#   " best thing I can say about movie also most damning given Mamaw's proud indifference anyone's good opinion her. It's respectable.                ",
#   0.8809,
#   'Positive'],
#  ['Hillbilly Elegy',
#   'Danny Leigh',
#   '                November 21, 2020            ',
#   "                    On page Vance's Mamaw least had complexity a bad parent herself born others. Howard smooths syrups until she no more than Pez dispenser chain-smoking tough love.                ",
#   -0.25,
#   'Negative'],
#  ['Hillbilly Elegy',
#   'Perri Nemiroff',
#   '                November 21, 2020            ',
#   '                    Blunt emotional manipulation no valuable takeaway. Hillbilly Elegy a structural mess no nuance reduces its main players their most basic character descriptions nothing more.                ',
#   -0.7817,
#   'Negative'],
#  ['Hillbilly Elegy',
#   'Peter Travers',
#   '                November 20, 2020            ',
#   " movie dulls social edge J.D. Vance's memoir about Rust Belt's white working class but Glenn Close Amy Adams work hard make up difference. As Mamaw  chain-smoking matriarch  clan Close simply sensational.                ",
#   -0.2732,
#   'Negative'],
#  ['Hillbilly Elegy',
#   'Richard Whittaker',
#   '                November 20, 2020            ',
#   "                    Hillbilly Elegy artificial  near-meat  fried bologna sandwich J.D.'s sister serves him a good ol' taste home.                ",
#   0.4404,
#   'Positive'],
#  ['Hillbilly Elegy',
#   'Daniel Neman',
#   '                November 20, 2020            ',
#   '                    It as if Howard does not fully underst  people whose story is telling so feels compelled force-feed audience  obvious points is trying make.                ',
#   0.1226,
#   'Positive'],
#  ['Hillbilly Elegy',
#   'Donald Clarke',
#   '                November 20, 2020            ',
#   "                    One's brain aches pondering why anyone thought would be good idea.                ",
#   0.2263,
#   'Positive'],
#  ['Hillbilly Elegy',
#   'Kevin Maher',
#   '                November 20, 2020            ',
#   ' performances wildly uneven range from naturalistic  cartoonish.                ',
#   0.0,
#   'Neutral'],
#  ['Hillbilly Elegy',
#   'Sandra Hall',
#   '                November 19, 2020            ',
#   " book's hard political edges have been planed away leaving highly polished piece storytelling  great Hollywood tradition working-class soaps.                ",
#   0.5719,
#   'Positive'],
#  ['Hillbilly Elegy',
#   'Randy Myers',
#   '                November 19, 2020            ',
#   "                    Adams Close give their all but Howard's meek sanitized drama avoids harsh truths is counter what book all about.                ",
#   -0.296,
#   'Negative'],
#  ['Hillbilly Elegy',
#   'Adam Graham',
#   '                November 18, 2020            ',
#   '                    "Hillbilly Elegy" more interested histrionics of which there\'s plenty. Just don\'t look it any sense insight.                ',
#   0.4576,
#   'Positive'],
#  ['Hillbilly Elegy',
#   'Tim Robey',
#   '                November 18, 2020            ',
#   '                    Elegy four years late doomed.                ',
#   -0.6369,
#   'Negative'],
#  ['Hillbilly Elegy',
#   'Philip De Semlyen',
#   '                November 18, 2020            ',
#   '                    It may once have seemed like Oscar-winning proposition but Hillbilly Elegy arrives feeling more like ill-judged mind-numbing exercise Hollywoodsplaining heartl America.                ',
#   0.7343,
#   'Positive'],
#  ['Hillbilly Elegy',
#   'Mark Kermode',
#   '                November 17, 2020            ',
#   "                    It's surprising with so much going it how film never felt like inhabited spirit its material. You look it rather than watch it...                ",
#   0.1754,
#   'Positive'],
#  ['Hillbilly Elegy',
#   'Stephen Romei',
#   '                November 16, 2020            ',
#   '                    ... timeliness relevance this fine movie not diminished.                ',
#   0.25,
#   'Positive'],
#  ['Hillbilly Elegy',
#   'Angie Han',
#   '                November 14, 2020            ',
#   "                    Even though supposed be uplifting story about [J.D. Vance's] personal history it felt pretty generic.                ",
#   0.4939,
#   'Positive'],
#  ['Hillbilly Elegy',
#   'Richard Roeper',
#   '                November 14, 2020            ',
#   "                    Director Howard isn't one flashy tricks gimmicks but displays usual deft touch  material...                ",
#   0.0477,
#   'Neutral'],
#  ['Hillbilly Elegy',
#   'Clarisse Loughrey',
#   '                November 13, 2020            ',
#   '                    narrative belongs a writer who refuses admit larger place  world - a filmmaker who thinks a positive outlook alone can fix world.                ',
#   0.5267,
#   'Positive'],
#  ['Hillbilly Elegy',
#   'Matt Zoller Seitz',
#   '                November 12, 2020            ',
#   "                    It's not great or even particularly distinctive movie but heartfelt plain-spoken enough it might connect viewers whose families have dealt addiction recovery.                ",
#   0.5578,
#   'Positive'],
#  ['Hillbilly Elegy',
#   "Michael O'Sullivan",
#   '                November 11, 2020            ',
#   '                    story is painted a brush seems both narrowly specific overly broad.                ',
#   0.0,
#   'Neutral'],
#  ['Hillbilly Elegy',
#   'Ty Burr',
#   '                November 11, 2020            ',
#   " movie's neoliberal's fantasy a sociopolitical tract defanged. It will probably get nominated a lot awards.                ",
#   0.4588,
#   'Positive'],
#  ['Hillbilly Elegy',
#   'Nell Minow',
#   '                November 11, 2020            ',
#   '                    "Hillbilly Elegy" fails its one goal: give us sympathetic relatable portrait people we might dismiss. It never knows what story is trying tell.                ',
#   0.128,
#   'Positive'],
#  ['Hillbilly Elegy',
#   'Madeleine Seidel',
#   '                November 11, 2020            ',
#   '                    spineless trite melodrama leans easy moralising lazy stereotypes.                ',
#   -0.1027,
#   'Negative'],
#  ['Hillbilly Elegy',
#   'Jake Coyle',
#   '                November 11, 2020            ',
#   '                    Howard a humane sensitive director has made film full empathy missing wider lens.                ',
#   -0.296,
#   'Negative'],
#  ['Hillbilly Elegy',
#   'G. Allen Johnson',
#   '                November 11, 2020            ',
#   '                    [An] absorbing family drama rural poverty addiction features compelling go-for-broke performances from Amy Adams Glenn Close but rather bl lead Gabriel Basso Vance.                ',
#   0.5789,
#   'Positive'],
#  ['Hillbilly Elegy',
#   'Robert Daniels',
#   '                November 11, 2020            ',
#   "                    Hillbilly Elegy conflates one man's story emblematic a community in short-sighted terms. It isn't just disservice Vance but  inhabitants  Rust Belt well.                ",
#   0.2617,
#   'Positive'],
#  ['Hillbilly Elegy',
#   'Johnny Oleksinski',
#   '                November 10, 2020            ',
#   '                    "Hillbilly Elegy" a series rotten choices - occasionally by characters but mostly by Hollywood.                ',
#   -0.2846,
#   'Negative'],
#  ['Hillbilly Elegy',
#   'Barry Hertz',
#   '                November 10, 2020            ',
#   "                    Ron Howard's Hillbilly Elegy a bad film inert clichéd largely devoid cinematic imagination.                ",
#   -0.5423,
#   'Negative'],
#  ['Hillbilly Elegy',
#   'Justin Chang',
#   '                November 10, 2020            ',
#   '                    Directed by Ron Howard denuded any meaningful politics speak of "Hillbilly Elegy" an extended Oscar-clip montage search a larger purpose an unwieldy slop bucket door-smashing child-slapping husband-immolating histrionics.                ',
#   0.3182,
#   'Positive'],
#  ['Hillbilly Elegy',
#   'Katie Rife',
#   '                November 10, 2020            ',
#   '                    Hillbilly Elegy just reinforces stereotypes insists illuminating.                ',
#   0.0,
#   'Neutral'],
#  ['Hillbilly Elegy',
#   'Fionnuala Halligan',
#   '                November 10, 2020            ',
#   '                    high-spec high-wattage drama which both entirely suitable for  should play well on  streaming service which supported it.                ',
#   0.7003,
#   'Positive'],
#  ['Hillbilly Elegy',
#   'Alonso Duralde',
#   '                November 10, 2020            ',
#   "                    It isn't interested  systems create poverty addiction ignorance; just wants pretend one straight white guy's ability rise above surroundings means there's no excuse everyone else not have done so well.                ",
#   -0.5503,
#   'Negative'],
#  ['Hillbilly Elegy',
#   'Alissa Wilkinson',
#   '                November 10, 2020            ',
#   "                    An elegy a mournful poem reflection. Often it's lament a song sung  dead. Hillbilly Elegy no elegy. It's not reflective enough even underst  living.                ",
#   -0.9022,
#   'Negative'],
#  ['Hillbilly Elegy',
#   'Richard Lawson',
#   '                November 10, 2020            ',
#   '                    This prestige bait uses awfully rusty lure tossed careless pride from its ship Hollywood fools.                ',
#   -0.5106,
#   'Negative'],
#  ['Hillbilly Elegy',
#   'Terri White',
#   '                November 10, 2020            ',
#   '                    In spite A-list acting directing talent this a tick-the-boxes recovery redemption true story never rings true.                ',
#   -0.0341,
#   'Neutral'],
#  ['Hillbilly Elegy',
#   'David Ehrlich',
#   '                November 10, 2020            ',
#   '                    For all  favors Howard does  subject his biopic  director can only do so much disguise self-serving nature a story was always less about where Vance came from than was about where wanted go.                ',
#   -0.0717,
#   'Negative'],
#  ['Hillbilly Elegy',
#   'Peter Bradshaw',
#   '                November 10, 2020            ',
#   '                    This a well-meant story someone pulling himself up by bootstraps with some help from grandma. it feels contrived self-conscious.                ',
#   0.4019,
#   'Positive'],
#  ['Hillbilly Elegy',
#   'Sheri Linden',
#   '                November 10, 2020            ',
#   "                    Whatever lessons might want impart Hillbilly Elegy doesn't romanticize its subjects or package their struggles neat bromides or cornpone redemption.                ",
#   -0.1361,
#   'Negative'],
#  ['Hillbilly Elegy',
#   'Bill Goodykoontz',
#   '                November 10, 2020            ',
#   '                    "Hillbilly Elegy" ultimately not movie lot people thought would be. Whether that\'s good or bad thing you\'ll have decide after you\'ve seen it.                ',
#   -0.1531,
#   'Negative'],
#  ['Hillbilly Elegy',
#   'Brian Truitt',
#   '                November 10, 2020            ',
#   '                    Without truly distinguishing "Hillbilly" charm it\'s simply middling dysfunctional family drama A-list actresses.                ',
#   0.0757,
#   'Positive'],
#  ['Hillbilly Elegy',
#   'Owen Gleiberman',
#   '                November 10, 2020            ',
#   "                    There's weird bl flaw  center this adaptation.                ",
#   0.3818,
#   'Positive'],
#  ['Hillbilly Elegy',
#   'Chris Barsanti',
#   '                November 10, 2020            ',
#   '                    Hillbilly Elegy feels like bl feel-good story rather than one part a longer tragedy no clear end.                ',
#   -0.1984,
#   'Negative']]

# %%
# Web scrapping from reviews of movies from Rotten Tomatoes
# Movie: Bourne Identity
# Import libraries
import requests
from bs4 import BeautifulSoup

import re

#SA: vadar sentiment analyzer library
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

#SA: sentiment analyzer instance
analyser = SentimentIntensityAnalyzer()

# Collect first page of artists’ list (Collecting and Parsing data)
page = requests.get('https://www.rottentomatoes.com/m/bourne_identity/reviews')

# Create a BeautifulSoup object
soup = BeautifulSoup(page.text, 'html.parser')

# Pull all text from the review 
Bourne_identity = soup.find(class_='review_table')

# Remove tag <span>
for match in Bourne_identity.findAll('span'):
    match.unwrap()

# Pull text from all instances of <h6> tag within BodyText div
bourne_review = Bourne_identity.find_all(class_='the_review')

# Pull text from all instances of 'cast' tag within BodyText div
bourne_date = Bourne_identity.find_all(class_='review-date subtle small')

# Pull text from all instances of 'genre' tag within BodyText div
bourne_critic = Bourne_identity.find_all(class_='unstyled bold articleLink')

comments = []
for review in bourne_review:
    rev = review.contents[0]
    rev = re.sub('\r\n', '', rev)
    patt = re.compile('(\s*) The | in | of | and | a | that | to | is | for | on |&mdash; | with | but | was | are | as |the | this | you | his | they | They | has | A | at | he | But | a | the | of |and | it | it\'s | an |,(\s*)')
    rev = patt.sub(' ', rev)
    comments.append(rev)

dates = []
for date in bourne_date:
    dat = date.contents[0]
    dat = re.sub('\r\n', '', dat)
    dates.append(dat)

critics = []
for critic in bourne_critic:
    crit = critic.contents[0]
    crit = re.sub('\r\n', '', crit)
    critics.append(crit)

# Collect first page of artists’ list (Collecting and Parsing data)
page = requests.get('https://www.rottentomatoes.com/m/bourne_identity/reviews?type=&sort=&page=2')

# Create a BeautifulSoup object
soup = BeautifulSoup(page.text, 'html.parser')

# Pull all text from the review 
Bourne_identity = soup.find(class_='review_table')

# Remove tag <span>
for match in Bourne_identity.findAll('span'):
    match.unwrap()

# Pull text from all instances of <h6> tag within BodyText div
bourne_review = Bourne_identity.find_all(class_='the_review')

# Pull text from all instances of 'cast' tag within BodyText div
bourne_date = Bourne_identity.find_all(class_='review-date subtle small')

# Pull text from all instances of 'genre' tag within BodyText div
bourne_critic = Bourne_identity.find_all(class_='unstyled bold articleLink')

for review in bourne_review:
    rev = review.contents[0]
    rev = re.sub('\r\n', '', rev)
    patt = re.compile('(\s*) The | in | of | and | a | that | to | is | for | on |&mdash; | with | but | was | are | as |the | this | you | his | they | They | has | A | at | he | But | a | the | of |and | it | it\'s | an |,(\s*)')
    rev = patt.sub(' ', rev)
    comments.append(rev)

for date in bourne_date:
    dat = date.contents[0]
    dat = re.sub('\r\n', '', dat)
    dates.append(dat)

for critic in bourne_critic:
    crit = critic.contents[0]
    crit = re.sub('\r\n', '', crit)
    critics.append(crit)

# Collect first page of artists’ list (Collecting and Parsing data)
page = requests.get('https://www.rottentomatoes.com/m/bourne_identity/reviews?type=&sort=&page=3')

# Create a BeautifulSoup object
soup = BeautifulSoup(page.text, 'html.parser')

# Pull all text from the review 
Bourne_identity = soup.find(class_='review_table')

# Remove tag <span>
for match in Bourne_identity.findAll('span'):
    match.unwrap()

# Pull text from all instances of <h6> tag within BodyText div
bourne_review = Bourne_identity.find_all(class_='the_review')

# Pull text from all instances of 'cast' tag within BodyText div
bourne_date = Bourne_identity.find_all(class_='review-date subtle small')

# Pull text from all instances of 'genre' tag within BodyText div
bourne_critic = Bourne_identity.find_all(class_='unstyled bold articleLink')

for review in bourne_review:
    rev = review.contents[0]
    rev = re.sub('\r\n', '', rev)
    patt = re.compile('(\s*) The | in | of | and | a | that | to | is | for | on |&mdash; | with | but | was | are | as |the | this | you | his | they | They | has | A | at | he | But | a | the | of |and | it | it\'s | an |,(\s*)')
    rev = patt.sub(' ', rev)
    comments.append(rev)

for date in bourne_date:
    dat = date.contents[0]
    dat = re.sub('\r\n', '', dat)
    dates.append(dat)

for critic in bourne_critic:
    crit = critic.contents[0]
    crit = re.sub('\r\n', '', crit)
    critics.append(crit)

reviews_bourne_identity = []
for i in range (0,59):
    record = []
    record.append('Bourne Identity')
    record.append(critics[i])
    record.append(dates[i])
    record.append(comments[i])
        
    #SA: appending compound scores and categories
    sentiment_rev = analyser.polarity_scores(comments[i])
    record.append(sentiment_rev['compound'])

    #SA: Classificatin of compound score
    if sentiment_rev['compound'] >= 0.05:
        record.append('Positive')
    elif sentiment_rev['compound'] <= - 0.05:
        record.append('Negative')
    else:
        record.append('Neutral')
    
    reviews_bourne_identity.append(record)
    
reviews_bourne_identity
# Out:
# [['Bourne Identity',
#   'Film Companion Staff',
#   '                October 27, 2020            ',
#   "                    One man's heart-pounding crusade tear down crooked system created him...                ",
#   0.25,
#   'Positive'],
#  ['Bourne Identity',
#   'Mike Massie',
#   '                September 29, 2020            ',
#   '                    Although basic amnesia plot sets up potential excitement  editing immediately becomes most detrimental component  action-packed world Jason Bourne.                ',
#   0.4939,
#   'Positive'],
#  ['Bourne Identity',
#   'Leigh Paatsch',
#   '                April 30, 2020            ',
#   ' franchise took marked upturn later instalments but fair first entry nonetheless.                ',
#   0.4497,
#   'Positive'],
#  ['Bourne Identity',
#   'Namrata Joshi',
#   '                January 3, 2019            ',
#   ' body language personality Damon invests Bourne creates impression intelligence depth however specious these qualities may ultimately be.                ',
#   0.7269,
#   'Positive'],
#  ['Bourne Identity',
#   'Tim Brayton',
#   '                December 5, 2016            ',
#   '                    Breathtakingly beautifully simple.                ',
#   0.5719,
#   'Positive'],
#  ['Bourne Identity',
#   'Jess Lomas',
#   '                July 7, 2014            ',
#   "                    Whether consider a smart thriller or paint-by-numbers spy caper The Bourne Identity a dynamic interpretation Robert Ludlum's bestselling novel.                ",
#   0.7906,
#   'Positive'],
#  ['Bourne Identity',
#   'Sierra Filucci',
#   '                January 1, 2011            ',
#   '                    Violent thrilling first  Bourne action trilogy.                ',
#   -0.2023,
#   'Negative'],
#  ['Bourne Identity',
#   'Cole Smithey',
#   '                February 28, 2010            ',
#   '                    "The Bourne Identity" a well-written action spy film stays true its espionage thriller genre while inflicting flinch-inducing moments pure cinematic action.                ',
#   0.4939,
#   'Positive'],
#  ['Bourne Identity',
#   'Guylaine Cadorette',
#   '                September 8, 2009            ',
#   '                    suspenseful thriller showcases stunning visuals great acting a story will keep entertained from start finish.                ',
#   0.8689,
#   'Positive'],
#  ['Bourne Identity',
#   'Felix Vasquez Jr.',
#   '                April 29, 2009            ',
#   '                    This a long sweet breath fresh air  action genre...                ',
#   0.6486,
#   'Positive'],
#  ['Bourne Identity',
#   'Mark Halverson',
#   '                August 7, 2008            ',
#   '                    Farfetched plotting nearly capsizes globe-trotting thriller director Doug Liman certainly keeps international intrigue testosterone flowing an entertaining clip.                ',
#   0.6908,
#   'Positive'],
#  ['Bourne Identity',
#   'Todd McCarthy',
#   '                June 12, 2008            ',
#   '                    first-rate thriller grit intrigue spare.                ',
#   0.1027,
#   'Positive'],
#  ['Bourne Identity',
#   'Beth Accomando',
#   '                August 3, 2007            ',
#   '                    You may be surprised by fact this formula spy thriller been delivered a matter-of-fact efficiency proves highly entertaining.                ',
#   0.7902,
#   'Positive'],
#  ['Bourne Identity',
#   'Christopher Smith',
#   '                July 26, 2007            ',
#   '                    sleek espionage thriller reduces world  size a postage stamp. Matt Damon terrific.                ',
#   0.5423,
#   'Positive'],
#  ['Bourne Identity',
#   'Rob Gonsalves',
#   '                July 23, 2007            ',
#   " movie about muscular speed skill  that's all about. Like its hero it's blank by design.                ",
#   0.7269,
#   'Positive'],
#  ['Bourne Identity',
#   'Emma Cochrane',
#   '                December 30, 2006            ',
#   '                    For once a sequel would be welcome.                ',
#   0.4588,
#   'Positive'],
#  ['Bourne Identity',
#   'Stuart Klawans',
#   '                February 9, 2006            ',
#   '                    Efficient set pieces come neatly spaced every ten 15 minutes -- just often enough keep credulous --  trans-European settings lend classy backdrop.                ',
#   0.7964,
#   'Positive'],
#  ['Bourne Identity',
#   'Vic Holtreman',
#   '                March 3, 2005            ',
#   '                    ...Liman also clever enough make real action start when motor stops.                ',
#   0.34,
#   'Positive'],
#  ['Bourne Identity',
#   'Jeffrey Overstreet',
#   '                January 15, 2005            ',
#   "                    Plenty very cool fight scenes edited such although are fast-paced you can actually see what's happening.                ",
#   -0.0735,
#   'Negative'],
#  ['Bourne Identity',
#   'Tony Medley',
#   '                December 6, 2004            ',
#   ' Bourne Identity an intense violent bite-your-nails-to-the-quick thriller.                ',
#   -0.4939,
#   'Negative'],
#  ['Bourne Identity',
#   'Daniel Kasman',
#   '                October 7, 2004            ',
#   "                    One  many problems other than Damon's lack emotion is fact there's no suspense.                ",
#   -0.7351,
#   'Negative'],
#  ['Bourne Identity',
#   'Thomas Delapa',
#   '                August 7, 2004            ',
#   "                    Also helped immeasurably by unusually cool score by John Powell Mr. Liman also makes good use  European settings alternating between close ups Damon's frustrated face wider pans slurp up snow clad France setting.                ",
#   0.2716,
#   'Positive'],
#  ['Bourne Identity',
#   'Abbie Bernstein',
#   '                July 23, 2004            ',
#   '                    ...puts snap crackle pop back into spy thriller.                ',
#   0.1027,
#   'Positive'],
#  ['Bourne Identity',
#   'Charlie Brown',
#   '                February 4, 2004            ',
#   "                    It's got plenty mystery (starting  one hinted in title) lots action several cities full exotic-to-Americans scenery a likable hero a bit romance  faintest whiff existential philosophy.                ",
#   0.802,
#   'Positive'],
#  ['Bourne Identity',
#   'Michael Dequina',
#   '                February 1, 2004            ',
#   ' result an intriguingly paced thriller knows how milk some excitement out smaller scenes.                ',
#   0.5574,
#   'Positive'],
#  ['Bourne Identity',
#   'Greg Maki',
#   '                January 12, 2004            ',
#   '                    All style cannot make up  flagging energy level  narrative.                ',
#   0.2732,
#   'Positive'],
#  ['Bourne Identity',
#   'Scott Nash',
#   '                January 7, 2004            ',
#   "                    ... With its script problems it's probably better than should be ...                ",
#   0.0516,
#   'Positive'],
#  ['Bourne Identity',
#   'Pablo Villaça',
#   '                September 27, 2003            ',
#   '                    Typical light summer fare.                ',
#   0.0,
#   'Neutral'],
#  ['Bourne Identity',
#   'Harry Guerin',
#   '                July 25, 2003            ',
#   '                    As cenas de ação são ótimas e há boa química entre Damon e Potente. O roteiro também é instigante embora não totalmente satisfatório.                ',
#   0.0,
#   'Neutral'],
#  ['Bourne Identity',
#   'John R. McEwen',
#   '                April 29, 2003            ',
#   "                    It's really safe bet Damon will be Bourne again.                ",
#   0.4927,
#   'Positive'],
#  ['Bourne Identity',
#   'Mark Robison',
#   '                February 8, 2003            ',
#   " Bourne Identity about effective thriller you could want especially if don't want think too hard.                ",
#   0.4431,
#   'Positive'],
#  ['Bourne Identity',
#   'Wesley Lovell',
#   '                January 27, 2003            ',
#   "                    I suspect I'll watch movie over over. It's simply blast.                ",
#   -0.296,
#   'Negative'],
#  ['Bourne Identity',
#   'Rebecca Murray',
#   '                January 8, 2003            ',
#   '                    Fast thrilling everything James Bond no longer is.                ',
#   0.2263,
#   'Positive'],
#  ['Bourne Identity',
#   'Michael Dequina',
#   '                December 17, 2002            ',
#   "                    Matt Damon proves he's more than up  task an action star.                ",
#   0.0,
#   'Neutral'],
#  ['Bourne Identity',
#   'Nathaniel Rogers',
#   '                December 8, 2002            ',
#   "                    'A new action hero Bourne.' As incredibly cheesy precious advertising tag line The Bourne Identity is there's no discounting truth does hold.                ",
#   0.6615,
#   'Positive'],
#  ['Bourne Identity',
#   'Christopher Tookey',
#   '                November 11, 2002            ',
#   '                    While never reaches transcendence its genre it happens be pleasurably overstuffed smart welcome touches.                ',
#   0.8463,
#   'Positive'],
#  ['Bourne Identity',
#   'James Rocchi',
#   '                November 10, 2002            ',
#   '                    It resembles one those travelogue thrillers  1960s that were blown away by success James Bond.                ',
#   0.5859,
#   'Positive'],
#  ['Bourne Identity',
#   'Luis Martinez',
#   '                November 7, 2002            ',
#   "                    Matt Damon's amnesiac secret agent  run this immensely satisfying engagingly direct thriller.                ",
#   0.7096,
#   'Positive'],
#  ['Bourne Identity',
#   'Matthew Turner',
#   '                November 5, 2002            ',
#   '                    Buen thriller de espías con una gran cantidad de acción pero desgraciadamente con otra buena de dósis de huecos en el guión.                ',
#   0.1027,
#   'Positive'],
#  ['Bourne Identity',
#   'Margaret A. McGurk',
#   '                October 30, 2002            ',
#   '                    In short The Bourne Identity an excellent thriller is well-worth checking out.                ',
#   0.6249,
#   'Positive'],
#  ['Bourne Identity',
#   'Xan Brooks',
#   '                October 15, 2002            ',
#   ' movie may not be realistic but earns its stripes high-class escapist fare.                ',
#   0.0,
#   'Neutral'],
#  ['Bourne Identity',
#   'D.K. Holm',
#   '                October 2, 2002            ',
#   ' Bourne Identity a blockbuster without point... Despite its good-looking veneer its breakneck pace its daisy-chain expert set-pieces some crucial logic or motive appears have been junked along way.                ',
#   0.5994,
#   'Positive'],
#  ['Bourne Identity',
#   'David Nusair',
#   '                September 27, 2002            ',
#   "                    In adapting Ludlum's complex novel Liman & Co. solved number narrative problems.                ",
#   0.25,
#   'Positive'],
#  ['Bourne Identity',
#   'Urban Cinefile Critics',
#   '                September 26, 2002            ',
#   "                    ...a passable effort receives plenty mileage out Damon's expectedly engaging performance...                ",
#   0.34,
#   'Positive'],
#  ['Bourne Identity',
#   'Brent Simon',
#   '                August 31, 2002            ',
#   ' Bourne Identity delivers everything ask in thriller - nail-biting suspense awe-inspiring stunts a resolution satisfying  film itself.                ',
#   0.5267,
#   'Positive'],
#  ['Bourne Identity',
#   'Mark Palermo',
#   '                August 26, 2002            ',
#   '                    Spry alive possibility [but] also dramatically consequential... first spy thriller a good while successfully marry intentions deeds.                ',
#   0.8898,
#   'Positive'],
#  ['Bourne Identity',
#   'Neil Smith',
#   '                August 22, 2002            ',
#   " Paris locations as central flavour here they've been any espionage film since 1963's Charade.                ",
#   0.0,
#   'Neutral'],
#  ['Bourne Identity',
#   'Joshua Tyler',
#   '                August 20, 2002            ',
#   '                    fast-paced unpredictable edgy yarn breathes new life into espionage thriller genre.                ',
#   0.1027,
#   'Positive'],
#  ['Bourne Identity',
#   'Ben Kenigsberg',
#   '                August 12, 2002            ',
#   '                    Now our world much more complex  enemies much more gray. Bourne Identity a clear product that gray area but somehow still harkens back  good old days when spy still spy.                ',
#   0.5285,
#   'Positive'],
#  ['Bourne Identity',
#   'Philip Martin',
#   '                August 8, 2002            ',
#   " film may be more a mess than inside Bourne's head but its quirks strangely enough are what keep interesting.                ",
#   -0.0359,
#   'Neutral'],
#  ['Bourne Identity',
#   'Andrew Sarris',
#   '                July 26, 2002            ',
#   '                    ...great kinetic silly fun.                ',
#   0.8176,
#   'Positive'],
#  ['Bourne Identity',
#   'Dan Marcucci and Nancy Serougi',
#   '                July 25, 2002            ',
#   '                    rollicking adventure yarn.                ',
#   0.3182,
#   'Positive'],
#  ['Bourne Identity',
#   'Mark Caro',
#   '                July 23, 2002            ',
#   '                    Aside from turning me away from CIA this a good flick.                ',
#   0.4404,
#   'Positive'],
#  ['Bourne Identity',
#   'Marshall Fine',
#   '                July 20, 2002            ',
#   " Bourne Identity no mere summer amusement park ride. It's gray Go colorful a cool contrast its source material.                ",
#   0.3818,
#   'Positive'],
#  ['Bourne Identity',
#   'Rich Cline',
#   '                July 15, 2002            ',
#   '                    Damon captures sense a good man awakening from nightmare turns out have been actual life.                ',
#   0.4404,
#   'Positive'],
#  ['Bourne Identity',
#   'Jeffrey Chen',
#   '                July 14, 2002            ',
#   "                    Twists turns keep story increasingly complex gripping even if director Liman doesn't really pump up adrenaline.                ",
#   0.0,
#   'Neutral'],
#  ['Bourne Identity',
#   'Jim Chastain',
#   '                July 12, 2002            ',
#   '                    well-executed spy-thriller.                ',
#   0.0,
#   'Neutral'],
#  ['Bourne Identity',
#   'Gabriel Shanks',
#   '                July 1, 2002            ',
#   '                    An edgy thriller delivers surprising punch.                ',
#   0.3612,
#   'Positive'],
#  ['Bourne Identity',
#   'Bruce Bennett',
#   '                June 29, 2002            ',
#   '                    Aspires be both whammo action blockbuster an intelligent think piece...a delicate balance any film pull off.                ',
#   0.7964,
#   'Positive']]

# %%
# Web scrapping from reviews of movies from Rotten Tomatoes
# Movie: I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS
# Import libraries
import requests
from bs4 import BeautifulSoup

import re

#SA: vadar sentiment analyzer library
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

#SA: sentiment analyzer instance
analyser = SentimentIntensityAnalyzer()

# Collect first page of artists’ list (Collecting and Parsing data)
page = requests.get('https://www.rottentomatoes.com/m/i_am_big_bird_the_caroll_spinney_story/reviews')

# Create a BeautifulSoup object
soup = BeautifulSoup(page.text, 'html.parser')

# Pull all text from the review 
big_bird = soup.find(class_='review_table')

# Remove tag <span>
for match in big_bird.findAll('span'):
    match.unwrap()

# Pull text from all instances of <h6> tag within BodyText div
bird_review = big_bird.find_all(class_='the_review')

# Pull text from all instances of 'cast' tag within BodyText div
bird_date = big_bird.find_all(class_='review-date subtle small')

# Pull text from all instances of 'genre' tag within BodyText div
bird_critic = big_bird.find_all(class_='unstyled bold articleLink')

comments = []
for review in bird_review:
    rev = review.contents[0]
    rev = re.sub('\r\n', '', rev)
    patt = re.compile('(\s*) The | in | of | and | a | that | to | is | for | on |&mdash; | with | but | was | are | as |the | this | you | his | they | They | has | A | at | he | But | a | the | of |and | it | it\'s | an |,(\s*)')
    rev = patt.sub(' ', rev)
    comments.append(rev)

dates = []
for date in bird_date:
    dat = date.contents[0]
    dat = re.sub('\r\n', '', dat)
    dates.append(dat)

critics = []
for critic in bird_critic:
    crit = critic.contents[0]
    crit = re.sub('\r\n', '', crit)
    critics.append(crit)

# Collect first page of artists’ list (Collecting and Parsing data)
page = requests.get('https://www.rottentomatoes.com/m/i_am_big_bird_the_caroll_spinney_story/reviews?type=&sort=&page=2')

# Create a BeautifulSoup object
soup = BeautifulSoup(page.text, 'html.parser')

# Pull all text from the review 
big_bird = soup.find(class_='review_table')

# Remove tag <span>
for match in big_bird.findAll('span'):
    match.unwrap()

# Pull text from all instances of <h6> tag within BodyText div
bird_review = big_bird.find_all(class_='the_review')

# Pull text from all instances of 'cast' tag within BodyText div
bird_date = big_bird.find_all(class_='review-date subtle small')

# Pull text from all instances of 'genre' tag within BodyText div
bird_critic = big_bird.find_all(class_='unstyled bold articleLink')

for review in bird_review:
    rev = review.contents[0]
    rev = re.sub('\r\n', '', rev)
    patt = re.compile('(\s*) The | in | of | and | a | that | to | is | for | on |&mdash; | with | but | was | are | as |the | this | you | his | they | They | has | A | at | he | But | a | the | of |and | it | it\'s | an |,(\s*)')
    rev = patt.sub(' ', rev)
    comments.append(rev)

for date in bird_date:
    dat = date.contents[0]
    dat = re.sub('\r\n', '', dat)
    dates.append(dat)

for critic in bird_critic:
    crit = critic.contents[0]
    crit = re.sub('\r\n', '', crit)
    critics.append(crit)
    
# Collect first page of artists’ list (Collecting and Parsing data)
page = requests.get('https://www.rottentomatoes.com/m/i_am_big_bird_the_caroll_spinney_story/reviews?type=&sort=&page=3')

# Create a BeautifulSoup object
soup = BeautifulSoup(page.text, 'html.parser')

# Pull all text from the review 
big_bird = soup.find(class_='review_table')

# Remove tag <span>
for match in big_bird.findAll('span'):
    match.unwrap()

# Pull text from all instances of <h6> tag within BodyText div
bird_review = big_bird.find_all(class_='the_review')

# Pull text from all instances of 'cast' tag within BodyText div
bird_date = big_bird.find_all(class_='review-date subtle small')

# Pull text from all instances of 'genre' tag within BodyText div
bird_critic = big_bird.find_all(class_='unstyled bold articleLink')

for review in bird_review:
    rev = review.contents[0]
    rev = re.sub('\r\n', '', rev)
    patt = re.compile('(\s*) The | in | of | and | a | that | to | is | for | on |&mdash; | with | but | was | are | as |the | this | you | his | they | They | has | A | at | he | But | a | the | of |and | it | it\'s | an |,(\s*)')
    rev = patt.sub(' ', rev)
    comments.append(rev)

for date in bird_date:
    dat = date.contents[0]
    dat = re.sub('\r\n', '', dat)
    dates.append(dat)

for critic in bird_critic:
    crit = critic.contents[0]
    crit = re.sub('\r\n', '', crit)
    critics.append(crit)
    
reviews_big_bird = []
for i in range (0,59):
    record = []
    record.append('I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS')
    record.append(critics[i])
    record.append(dates[i])
    record.append(comments[i])
            
    #SA: appending compound scores and categories
    sentiment_rev = analyser.polarity_scores(comments[i])
    record.append(sentiment_rev['compound'])

    #SA: Classificatin of compound score
    if sentiment_rev['compound'] >= 0.05:
        record.append('Positive')
    elif sentiment_rev['compound'] <= - 0.05:
        record.append('Negative')
    else:
        record.append('Neutral')
        
    reviews_big_bird.append(record)
    
reviews_big_bird
# Out:
# [['I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS',
#   'Allen Almachar',
#   '                July 21, 2020            ',
#   "                    I Am Big Bird may not offer grandiose revelations ... it does provide glimpse into person who's touched more lives than some even aware of.                ",
#   0.0,
#   'Neutral'],
#  ['I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS',
#   'Brent McKnight',
#   '                July 5, 2020            ',
#   "                    It's impossible not walk away a smile your face.                ",
#   0.3612,
#   'Positive'],
#  ['I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS',
#   'Elissa Suh',
#   '                March 16, 2020            ',
#   "                    Who  man inside feathered suit? David LaMattina Chad N. Walker's straightforward documentary I Am Big Bird: Caroll Spinney Story explores just that giving face man behind bird since its inception.                ",
#   0.34,
#   'Positive'],
#  ['I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS',
#   'Daniel Barnes',
#   '                July 22, 2019            ',
#   '                    An open affecting look  little white-haired man inside  giant yellow suit.                ',
#   0.0,
#   'Neutral'],
#  ['I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS',
#   'Matthew Lucas',
#   '                July 5, 2019            ',
#   '                    truly magical experience from start finish with heart big kind  bird himself.                ',
#   0.8885,
#   'Positive'],
#  ['I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS',
#   'C.J. Prince',
#   '                June 20, 2019            ',
#   " problem that LaMattina Walker refuse let Spinney's story brea for single moment instead relying a barrage maudlin tactics choke tears out viewers.                ",
#   -0.8519,
#   'Negative'],
#  ['I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS',
#   'Neely Swanson',
#   '                September 15, 2017            ',
#   '                    I Am Big Bird: Caroll Spinney Story"  delightful heartwarming story  man inside head  8 foot tall 6 year old who crossed borders transcended politics breached intractable boundaries enriched lives from inception.                ',
#   0.7845,
#   'Positive'],
#  ['I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS',
#   'Jonathan Kiefer',
#   '                August 24, 2017            ',
#   '                    slathering sentimentally triumphant music emphasizes what seems like feeling protectiveness their subject but fair enough.                ',
#   0.7964,
#   'Positive'],
#  ['I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS',
#   'Peter Calder',
#   '                May 16, 2016            ',
#   '                    It plays like extended promo washed a score elevator-music strings  composed so many talking-head snatches it often feels like trailer itself.                ',
#   0.7184,
#   'Positive'],
#  ['I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS',
#   'Norman Wilner',
#   '                December 18, 2015            ',
#   "                    It's amazing a documentary so clumsy such incredible highs lows but that's power Big Bird you.                ",
#   0.217,
#   'Positive'],
#  ['I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS',
#   'Beth Accomando',
#   '                November 9, 2015            ',
#   '                    I Am Big Bird not great filmmaking it pays fitting tribute Spinney  character into which invested so much his own personality.                ',
#   -0.5096,
#   'Negative'],
#  ['I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS',
#   'Leigh Paatsch',
#   '                July 31, 2015            ',
#   ' purity intent sophisticated craft [Spinney] poured into their creation remains unacknowledged by general public. modestly appointed crowd-funded documentary I Am Big Bird should clear up oversight once for all.                ',
#   0.8074,
#   'Positive'],
#  ['I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS',
#   'Jarrod Walker',
#   '                July 30, 2015            ',
#   '                    Spinney well-deserving  attention  from standpoint sheer curiosity fascination knowing more about man who created character we loved children that our children now love is gently poignant experience.                ',
#   0.946,
#   'Positive'],
#  ['I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS',
#   'Andrew L. Urban',
#   '                July 27, 2015            ',
#   "                    This adulatory doco Spinney's life work a handful love stories glued together by Spinney who at centre it. kinda This Your Life doco                ",
#   0.6369,
#   'Positive'],
#  ['I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS',
#   "Michael O'Sullivan",
#   '                June 25, 2015            ',
#   "                    There's little sour temper sweetness this portrait.                ",
#   0.1065,
#   'Positive'],
#  ['I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS',
#   'Frank Swietek',
#   '                June 19, 2015            ',
#   '                    While nice--arguably too nice in fact--it feels like fifty minutes material drawn out nearly ninety.                ',
#   0.6486,
#   'Positive'],
#  ['I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS',
#   'Moira MacDonald',
#   '                June 18, 2015            ',
#   '                    Though its gooey sentimental soundtrack a misstep - story quite sweet enough already - "I Am Big Bird" mesmerizing anyone ( that\'s lot us) who grew up "Sesame Street."                ',
#   0.6801,
#   'Positive'],
#  ['I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS',
#   'Dave McGinn',
#   '                May 29, 2015            ',
#   '                    Very much heartwarming tribute bordering treacly.                ',
#   0.5233,
#   'Positive'],
#  ['I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS',
#   'Jim Slotek',
#   '                May 28, 2015            ',
#   "                    Spinney a one-of-a-kind personality an oddball even among oddballs who pioneered Sesame Street's Children's Television Workshop.                ",
#   0.0,
#   'Neutral'],
#  ['I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS',
#   'Stephen Silver',
#   '                May 22, 2015            ',
#   "                    In less than 90 minutes it's reasonably complete history  big Bird character  man it.                ",
#   0.0,
#   'Neutral'],
#  ['I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS',
#   'James Rocchi',
#   '                May 22, 2015            ',
#   "                    Not definitive story Sesame Street but a superb portrait one its longest residents  a peek behind scenes well worth taking anyone who grew up one pop culture's most identifiable most long-lived children's icons.                ",
#   0.8922,
#   'Positive'],
#  ['I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS',
#   'Tony Macklin',
#   '                May 21, 2015            ',
#   '                    Children love underst  majestic galoot.                ',
#   0.6369,
#   'Positive'],
#  ['I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS',
#   'Blake Goble',
#   '                May 20, 2015            ',
#   "                    I Am Big Bird: Caroll Spinney Story for most part is puff piece. feather film if will. It's nice flavorful yellow a Nilla cookie.                ",
#   0.4215,
#   'Positive'],
#  ['I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS',
#   'Andrea Chase',
#   '                May 15, 2015            ',
#   '                    gentle sensitive film about gentle sensitive man.                ',
#   0.7003,
#   'Positive'],
#  ['I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS',
#   'Peter Rainer',
#   '                May 15, 2015            ',
#   '                    Affectionately saccharine.                ',
#   0.4939,
#   'Positive'],
#  ['I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS',
#   'Anita Katz',
#   '                May 15, 2015            ',
#   '                    Mushy times likable all over.                ',
#   0.0,
#   'Neutral'],
#  ['I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS',
#   'Nina Garin',
#   '                May 15, 2015            ',
#   '                    Yes there\'s lot information "I Am Big Bird " sometimes is bit self-serving. at heart a love story between Spinney that big yellow bird all us.                ',
#   0.9022,
#   'Positive'],
#  ['I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS',
#   'Marc Mohan',
#   '                May 15, 2015            ',
#   '                    With heyday "Sesame Street" undeniably  past "I Am Big Bird" will primarily appeal nostalgic grownups. as Spinney demonstrates you\'re never too old be kid heart.                ',
#   0.6369,
#   'Positive'],
#  ['I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS',
#   'Tom Long',
#   '                May 15, 2015            ',
#   '                    There\'s no ducking frank admiration love display "I Am Big Bird: Carroll Spinney Story." Then again there\'s lot love admire here. It\'s freaking Big Bird.                ',
#   0.9001,
#   'Positive'],
#  ['I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS',
#   'Mark Dujsik',
#   '                May 14, 2015            ',
#   '                    We get surface who man is but -- perhaps is testament  man himself -- we want know more.                ',
#   0.1154,
#   'Positive'],
#  ['I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS',
#   'Richard Roeper',
#   '                May 14, 2015            ',
#   '                    These sobering moments aside  great bulk "I Am Big Bird" a Sunny Day Sweepin\' Clouds Away brightly colored tribute  man his art.                ',
#   0.8225,
#   'Positive'],
#  ['I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS',
#   'Betsy Sharkey',
#   '                May 14, 2015            ',
#   " kind heartwarming sentimental tale a gentle soul  PBS show's iconic character would love.                ",
#   0.9423,
#   'Positive'],
#  ['I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS',
#   'J. R. Jones',
#   '                May 14, 2015            ',
#   '                    Behind-the-scenes footage provides some fascinating glimpses Sesame Street being blocked.                ',
#   0.34,
#   'Positive'],
#  ['I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS',
#   'Steven Rea',
#   '                May 14, 2015            ',
#   '                    Spinney comes across a man whose warm spirit literally  core  loving if loopy Big Bird.                ',
#   0.7579,
#   'Positive'],
#  ['I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS',
#   'Randy Cordova',
#   '                May 14, 2015            ',
#   '                    Befitting subject matter  movie sweet-natured sentimental.                ',
#   0.34,
#   'Positive'],
#  ['I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS',
#   'Walter V. Addiego',
#   '                May 14, 2015            ',
#   "                    celebration an artist who's utterly delighted international audience children - more than few adults.                ",
#   0.5563,
#   'Positive'],
#  ['I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS',
#   'Brian Orndorf',
#   '                May 14, 2015            ',
#   "                    Perhaps sharper exploration Spinney's life isn't presented but documentary gets by  basics supplying new perspective  puppeteer his legacy.                ",
#   0.1154,
#   'Positive'],
#  ['I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS',
#   'Sean Burns',
#   '                May 13, 2015            ',
#   "                    It impossible observe film's interviews Spinney not be taken aback by man's extraordinary sensitivity   deeply unhappy childhood seems still very much him today.                ",
#   -0.4754,
#   'Negative'],
#  ['I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS',
#   'Mike Scott',
#   '                May 12, 2015            ',
#   '                    Every bit warm kind-hearted  man whose story tells.                ',
#   0.2263,
#   'Positive'],
#  ['I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS',
#   'Ronnie Scheib',
#   '                May 11, 2015            ',
#   '                    Schmaltz continually threatens overcome genius this super-sentimental account gifted puppeteer Caroll Spinney.                ',
#   -0.3818,
#   'Negative'],
#  ['I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS',
#   "Sheila O'Malley",
#   '                May 8, 2015            ',
#   '                    "I Am Big Bird" a loving personal profile Spinney with memories anecdotes shared by wife his children his co-workers friends.                ',
#   0.8555,
#   'Positive'],
#  ['I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS',
#   'Laura Clifford',
#   '                May 7, 2015            ',
#   '                    Four years after "Being Elmo: Puppeteer\'s Journey" promoted idea a Muppet character embodied love along come documentarian duo Dave LaMattina Chad N. Walker reinstate legacy Sesame Street\'s original star.                ',
#   0.8519,
#   'Positive'],
#  ['I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS',
#   'Robin Clifford',
#   '                May 7, 2015            ',
#   ' main thing I got out "I Am Big Bird" this: Big Bird = unconditional love.                ',
#   0.6369,
#   'Positive'],
#  ['I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS',
#   'Linda Holmes',
#   '                May 7, 2015            ',
#   "                    For Muppet enthusiasts or just folks who like hear about unusual jobs it's worth seeking out.                ",
#   0.7003,
#   'Positive'],
#  ['I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS',
#   'Odie Henderson',
#   '                May 7, 2015            ',
#   '                    ...I Am Big Bird: Caroll Spinney Story a profoundly moving documentary.                ',
#   0.0,
#   'Neutral'],
#  ['I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS',
#   'Mike McGranaghan',
#   '                May 7, 2015            ',
#   '                    wonderful inspiring look how best art regardless  age group which aimed always comes a special personal touch makes indelible.                ',
#   0.9246,
#   'Positive'],
#  ['I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS',
#   'Jesse Hassenger',
#   '                May 7, 2015            ',
#   "                    Spinney's unassuming career worth celebrating even if doesn't provide much a story.                ",
#   0.6808,
#   'Positive'],
#  ['I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS',
#   'Mark Moring',
#   '                May 6, 2015            ',
#   '                    Charming fascinating.                ',
#   0.8074,
#   'Positive'],
#  ['I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS',
#   'Frank Scheck',
#   '                May 6, 2015            ',
#   "                    If there ever man lucky enough have found true calling life it's subject Dave LaMattina Chad N. Walker's affecting documentary.                ",
#   0.6808,
#   'Positive'],
#  ['I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS',
#   'Joe Neumaier',
#   '                May 6, 2015            ',
#   "                    You'll find few touching moments some iconic images Gen-X viewers but don't expect any feathers get ruffled.                ",
#   0.0,
#   'Neutral'],
#  ['I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS',
#   'Jen Chaney',
#   '                May 6, 2015            ',
#   '                    This a profile a decent man who permanently associated a revered pop-cultural icon.                ',
#   0.5106,
#   'Positive'],
#  ['I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS',
#   'David Noh',
#   '                May 6, 2015            ',
#   ' man lurking beneath all those Big Bird yellow feathers takes spotlight this highly endearing documentary.                ',
#   -0.128,
#   'Negative'],
#  ['I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS',
#   'Matt Prigge',
#   '                May 6, 2015            ',
#   '                    It gives  impression knowing him well  it does it amazingly while barely showing face.                ',
#   0.4588,
#   'Positive'],
#  ['I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS',
#   'Stephen Whitty',
#   '                May 6, 2015            ',
#   "                    We learn about highs lows Spinney's life  get some insight into character - character which not surprisingly seems have same capacity childlike wonder joy much-mourned Henson had.                ",
#   0.276,
#   'Positive'],
#  ['I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS',
#   'Neil Genzlinger',
#   '                May 5, 2015            ',
#   ' film gets little syrupy times but Mr. Spinney forthright engaging throughout.                ',
#   0.4767,
#   'Positive'],
#  ['I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS',
#   'Mark Kermode',
#   '                May 4, 2015            ',
#   "                    An incessantly schmaltzy TV score threatens drown us syrup but sight Big Bird singing It's Not Easy Being Green Jim Henson's memorial provides powerful emotional sucker-punch.                ",
#   -0.1677,
#   'Negative'],
#  ['I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS',
#   'Amber Wilkinson',
#   '                May 4, 2015            ',
#   " overall effect drenched by Joshua Johnson's unnecessarily surging score is far too portentous its own good.                ",
#   0.4404,
#   'Positive'],
#  ['I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS',
#   'Chuck Bowen',
#   '                May 3, 2015            ',
#   " transcendence  film offers isn't be taken lightly considering near impossibility living professionally an artist.                ",
#   0.0,
#   'Neutral'],
#  ['I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS',
#   'Adam Woodward',
#   '                May 1, 2015            ',
#   '                    One warm your cockles.                ',
#   0.2263,
#   'Positive']]

# %%
# Web scrapping from reviews of movies from Rotten Tomatoes
# Movie: You, me and Dupree
# Import libraries
import requests
from bs4 import BeautifulSoup

import re

#SA: vadar sentiment analyzer library
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

#SA: sentiment analyzer instance
analyser = SentimentIntensityAnalyzer()

# Collect first page of artists’ list (Collecting and Parsing data)
page = requests.get('https://www.rottentomatoes.com/m/you_me_and_dupree/reviews')

# Create a BeautifulSoup object
soup = BeautifulSoup(page.text, 'html.parser')

# Pull all text from the review 
dupree = soup.find(class_='review_table')

# Remove tag <span>
for match in big_bird.findAll('span'):
    match.unwrap()

# Pull text from all instances of <h6> tag within BodyText div
dupree_review = dupree.find_all(class_='the_review')

# Pull text from all instances of 'cast' tag within BodyText div
dupree_date = dupree.find_all(class_='review-date subtle small')

# Pull text from all instances of 'genre' tag within BodyText div
dupree_critic = dupree.find_all(class_='unstyled bold articleLink')

comments = []
for review in dupree_review:
    rev = review.contents[0]
    rev = re.sub('\r\n', '', rev)
    patt = re.compile('(\s*) The | in | of | and | a | that | to | is | for | on |&mdash; | with | but | was | are | as |the | this | you | his | they | They | has | A | at | he | But | a | the | of |and | it | it\'s | an |,(\s*)')
    rev = patt.sub(' ', rev)
    comments.append(rev)

dates = []
for date in dupree_date:
    dat = date.contents[0]
    dat = re.sub('\r\n', '', dat)
    dates.append(dat)

critics = []
for critic in dupree_critic:
    crit = critic.contents[0]
    crit = re.sub('\r\n', '', crit)
    critics.append(crit)

# Collect first page of artists’ list (Collecting and Parsing data)
page = requests.get('https://www.rottentomatoes.com/m/you_me_and_dupree/reviews?type=&sort=&page=2')

# Create a BeautifulSoup object
soup = BeautifulSoup(page.text, 'html.parser')

# Pull all text from the review 
dupree = soup.find(class_='review_table')

# Remove tag <span>
for match in big_bird.findAll('span'):
    match.unwrap()

# Pull text from all instances of <h6> tag within BodyText div
dupree_review = dupree.find_all(class_='the_review')

# Pull text from all instances of 'cast' tag within BodyText div
dupree_date = dupree.find_all(class_='review-date subtle small')

# Pull text from all instances of 'genre' tag within BodyText div
dupree_critic = dupree.find_all(class_='unstyled bold articleLink')

for review in dupree_review:
    rev = review.contents[0]
    rev = re.sub('\r\n', '', rev)
    patt = re.compile('(\s*) The | in | of | and | a | that | to | is | for | on |&mdash; | with | but | was | are | as |the | this | you | his | they | They | has | A | at | he | But | a | the | of |and | it | it\'s | an |,(\s*)')
    rev = patt.sub(' ', rev)
    comments.append(rev)

for date in dupree_date:
    dat = date.contents[0]
    dat = re.sub('\r\n', '', dat)
    dates.append(dat)

for critic in dupree_critic:
    crit = critic.contents[0]
    crit = re.sub('\r\n', '', crit)
    critics.append(crit)
    
# Collect first page of artists’ list (Collecting and Parsing data)
page = requests.get('https://www.rottentomatoes.com/m/you_me_and_dupree/reviews?type=&sort=&page=3')

# Create a BeautifulSoup object
soup = BeautifulSoup(page.text, 'html.parser')

# Pull all text from the review 
dupree = soup.find(class_='review_table')

# Remove tag <span>
for match in big_bird.findAll('span'):
    match.unwrap()

# Pull text from all instances of <h6> tag within BodyText div
dupree_review = dupree.find_all(class_='the_review')

# Pull text from all instances of 'cast' tag within BodyText div
dupree_date = dupree.find_all(class_='review-date subtle small')

# Pull text from all instances of 'genre' tag within BodyText div
dupree_critic = dupree.find_all(class_='unstyled bold articleLink')

for review in dupree_review:
    rev = review.contents[0]
    rev = re.sub('\r\n', '', rev)
    patt = re.compile('(\s*) The | in | of | and | a | that | to | is | for | on |&mdash; | with | but | was | are | as |the | this | you | his | they | They | has | A | at | he | But | a | the | of |and | it | it\'s | an |,(\s*)')
    rev = patt.sub(' ', rev)
    comments.append(rev)

for date in dupree_date:
    dat = date.contents[0]
    dat = re.sub('\r\n', '', dat)
    dates.append(dat)

for critic in dupree_critic:
    crit = critic.contents[0]
    crit = re.sub('\r\n', '', crit)
    critics.append(crit)

reviews_dupree = []
for i in range (0,59):
    record = []
    record.append('You me and Dupree')
    record.append(critics[i])
    record.append(dates[i])
    record.append(comments[i])
    
    #SA: appending compound scores and categories
    sentiment_rev = analyser.polarity_scores(comments[i])
    record.append(sentiment_rev['compound'])

    #SA: Classificatin of compound score
    if sentiment_rev['compound'] >= 0.05:
        record.append('Positive')
    elif sentiment_rev['compound'] <= - 0.05:
        record.append('Negative')
    else:
        record.append('Neutral')
            
    reviews_dupree.append(record)
    
reviews_dupree
# Out:
# [['You me and Dupree',
#   'Richard Propes',
#   '                September 27, 2020            ',
#   "                    Hudson isn't quite able carry film alone.                ",
#   -0.25,
#   'Negative'],
#  ['You me and Dupree',
#   'Leah Rozen',
#   '                April 22, 2020            ',
#   "                    You Me Dupree a slight meandering comedy that much like Dupree his wobbly bicycle spins its wheels doesn't get far.                ",
#   0.575,
#   'Positive'],
#  ['You me and Dupree',
#   'Ali Gray',
#   '                April 22, 2020            ',
#   "                    You Me And Dupree a film is almost instantly forgettable. Even now a few hours after watching it I'm struggling remember character names...                ",
#   -0.4215,
#   'Negative'],
#  ['You me and Dupree',
#   'John Ferguson',
#   '                April 22, 2020            ',
#   "                    Owen Wilson's laid-back slacker charm isn't enough carry flimsy contrived comedy vehicle...                ",
#   0.6369,
#   'Positive'],
#  ['You me and Dupree',
#   'Joel Siegel',
#   '                January 5, 2018            ',
#   ' situations this sitcom never get funny they should.                ',
#   -0.3412,
#   'Negative'],
#  ['You me and Dupree',
#   'Joshua Starnes',
#   '                December 28, 2010            ',
#   '                    You Me Dupree an inconsistent trifle - by turns cute annoying - not much more.                ',
#   0.0772,
#   'Positive'],
#  ['You me and Dupree',
#   'Fernando F. Croce',
#   '                August 30, 2009            ',
#   '                    Not single laugh here                ',
#   -0.4449,
#   'Negative'],
#  ['You me and Dupree',
#   'Devin Faraci',
#   '                February 27, 2009            ',
#   ' film a mishmash half-baked jokes sitcom scenarios Owen Wilson attempting float by his charm.                ',
#   0.5719,
#   'Positive'],
#  ['You me and Dupree',
#   'Kit Bowen',
#   '                November 20, 2008            ',
#   "                    ...playing off someone slightly wackier than himself really Wilson's forte in trying carry whole comedy his own he's not nearly successful...It also doesn't help Hudson Dillon aren't able pick up slack.                ",
#   0.2598,
#   'Positive'],
#  ['You me and Dupree',
#   'Jim Lane',
#   '                August 7, 2008            ',
#   '                    This one  worst scripts  history major-studio motion pictures: inconsistent undeveloped predictable poorly thought-out -- hopeless every level.                ',
#   -0.7964,
#   'Negative'],
#  ['You me and Dupree',
#   'Joe Lozito',
#   '                July 14, 2007            ',
#   "                    While Mr. Wilson a likeable guy small (re: supporting) doses a whole movie's worth his shtick can become tiresome.                ",
#   0.7783,
#   'Positive'],
#  ['You me and Dupree',
#   'Michael A. Smith',
#   '                December 13, 2006            ',
#   '                    ...Seth Rogen so funny "The 40-Year Old Virgin " gets laughs a husb who doesn\'t realize he\'s henpecked.                ',
#   0.787,
#   'Positive'],
#  ['You me and Dupree',
#   'Brent Simon',
#   '                September 17, 2006            ',
#   '                    Owen Wilson just does what does  allows to take or leave it. You Me Dupree then suffers slow start trades too frequently broad garish strokes before rallying some late atypical turns.                ',
#   -0.5106,
#   'Negative'],
#  ['You me and Dupree',
#   'Jim Chastain',
#   '                September 1, 2006            ',
#   "                    Wilson goes from crashing weddings crashing newlyweds a comedy that's tired week-old wedding cake.                ",
#   -0.1027,
#   'Negative'],
#  ['You me and Dupree',
#   'Christopher Smith',
#   '                August 30, 2006            ',
#   "                    An oddly likeable film grows you if you're willing stick it.                ",
#   0.4588,
#   'Positive'],
#  ['You me and Dupree',
#   'Philip French',
#   '                August 30, 2006            ',
#   "                    Between us let's just forget movie.                ",
#   -0.2263,
#   'Negative'],
#  ['You me and Dupree',
#   'David Edwards',
#   '                August 26, 2006            ',
#   '                    dire cuckoo-in-the-nest comedy.                ',
#   -0.128,
#   'Negative'],
#  ['You me and Dupree',
#   'Trevor Johnston',
#   '                August 25, 2006            ',
#   "                    There's odd giggle but nowhere near enough keep things going.                ",
#   0.0644,
#   'Positive'],
#  ['You me and Dupree',
#   'Matthew Turner',
#   '                August 24, 2006            ',
#   "                    bit dull since Dillon's constrained playing straight guy Hudson little work with  Douglas looks bored.                ",
#   -0.3612,
#   'Negative'],
#  ['You me and Dupree',
#   'Greg Maki',
#   '                August 24, 2006            ',
#   '                    Enjoyable comedy Owen Wilson fine comic form this a lot better than its trailer suggests.                ',
#   0.8442,
#   'Positive'],
#  ['You me and Dupree',
#   'Stella Papamichael',
#   '                August 22, 2006            ',
#   '                    ... As stale formulaic it gets.                ',
#   0.0,
#   'Neutral'],
#  ['You me and Dupree',
#   'Lori Hoffman',
#   '                August 22, 2006            ',
#   "                    It's not seamless but Wilson fans can safely roll out welcome mat.                ",
#   0.8519,
#   'Positive'],
#  ['You me and Dupree',
#   'Ted Murphy',
#   '                August 17, 2006            ',
#   '                    Despite clashing comedic styles a game cast ... finds few nuggets truth warmth  several full-tilt belly laughs.                ',
#   0.7385,
#   'Positive'],
#  ['You me and Dupree',
#   'Peter Canavese',
#   '                August 9, 2006            ',
#   '                    YOU ME AND DUPREE another a long line mediocre films be released 2006.                ',
#   0.0,
#   'Neutral'],
#  ['You me and Dupree',
#   'Hap Erstein',
#   '                August 8, 2006            ',
#   "                    What About Bob ain't.                ",
#   0.0,
#   'Neutral'],
#  ['You me and Dupree',
#   'Ross Anthony',
#   '                August 6, 2006            ',
#   "                    You Me Dupree overstays its welcome a compilation reel Wilson's scenes would make fairly funny viewing.                ",
#   0.7096,
#   'Positive'],
#  ['You me and Dupree',
#   'Audrey Rock-Richardson',
#   '                July 29, 2006            ',
#   "                    Although ends well (or least pretty good)  film can't seem make spark its bulk. During first half I laughed twice. That said it wasn't because Wilson.                ",
#   0.5727,
#   'Positive'],
#  ['You me and Dupree',
#   'Garry Maddox',
#   '                July 28, 2006            ',
#   '                    I laughed but was  expense my pride.                ',
#   0.6249,
#   'Positive'],
#  ['You me and Dupree',
#   'Michael Clawson',
#   '                July 28, 2006            ',
#   "                    Wilson riffs hard has moments but can't save comedy not enough laughs.                ",
#   -0.8673,
#   'Negative'],
#  ['You me and Dupree',
#   'Rich Cline',
#   '                July 27, 2006            ',
#   '                    Low IQs plague otherwise funny Wilson vehicle ...                ',
#   0.2023,
#   'Positive'],
#  ['You me and Dupree',
#   'Jonathan R. Perry',
#   '                July 27, 2006            ',
#   " filmmakers can't get balance right between comedy cruelty.                ",
#   -0.34,
#   'Negative'],
#  ['You me and Dupree',
#   'Michael Dequina',
#   '                July 26, 2006            ',
#   "                    This 'comedy' so clumsily executed wheezy a wonder anyone had resolve finish it.                ",
#   0.6249,
#   'Positive'],
#  ['You me and Dupree',
#   'James Kendrick',
#   '                July 23, 2006            ',
#   '                    Remarkably forced--ironic considering a starring vehicle an actor whose most defining quality his laid-back unaffected demeanor.                ',
#   0.0,
#   'Neutral'],
#  ['You me and Dupree',
#   'Brian Gibson',
#   '                July 23, 2006            ',
#   '                    Unfortunately directors Anthony Joe Russo sometimes push jokes too hard relying tired physical comedy easy visual jokes.                ',
#   0.4019,
#   'Positive'],
#  ['You me and Dupree',
#   'Jonathan W. Hickman',
#   '                July 22, 2006            ',
#   "                    Only good when Wilson's around . . .  end  hints misogyny  suggestions middle-class hollowness just blow away a puff cheery goodwill.                ",
#   0.7579,
#   'Positive'],
#  ['You me and Dupree',
#   'Urban Cinefile Critics',
#   '                July 22, 2006            ',
#   '                    terribly mediocre film squanders talent its stars a story could have been funny even thoughtful.                ',
#   0.5719,
#   'Positive'],
#  ['You me and Dupree',
#   'Mark Pfeiffer',
#   '                July 21, 2006            ',
#   '                    With its smart script an ultra-likeable cast You Me Dupree funny wacky plenty heart shifting focus beyond expectations ... best part  way relationships between three central characters change.                ',
#   0.9325,
#   'Positive'],
#  ['You me and Dupree',
#   'Steve Schneider',
#   '                July 20, 2006            ',
#   "                    Unfortunately You Me Dupree it's easier invest patience people stumbling find focus purpose than films searching  same things.                ",
#   0.1027,
#   'Positive'],
#  ['You me and Dupree',
#   'Matt Brunson',
#   '                July 20, 2006            ',
#   "                    Laugh-free derivative punishingly long 'comedy.'                ",
#   0.3612,
#   'Positive'],
#  ['You me and Dupree',
#   'Ken Hanke',
#   '                July 19, 2006            ',
#   '                    Inflicting pain -- both its characters on hapless audience members -- seems be play  day far this cesspool a movie concerned.                ',
#   -0.5106,
#   'Negative'],
#  ['You me and Dupree',
#   'Steven Snyder',
#   '                July 19, 2006            ',
#   '                    When our screening started there were 12 people a dog attendance. Before was over our number had dwindled by nine   dog had fallen asleep.                ',
#   -0.296,
#   'Negative'],
#  ['You me and Dupree',
#   'Brian Orndorf',
#   '                July 19, 2006            ',
#   "                    I wouldn't want spend five minutes these people a cab. Not hour together dinner. And sure hell not two hours together a movie theater.                ",
#   -0.5457,
#   'Negative'],
#  ['You me and Dupree',
#   'Mike McGranaghan',
#   '                July 19, 2006            ',
#   '                    In terms actual laughs this somewhere between scorching STD a sleepy corporate-gig Dennis Miller show.                ',
#   0.4939,
#   'Positive'],
#  ['You me and Dupree',
#   'Mark Palermo',
#   '                July 18, 2006            ',
#   '                    Like main character  movie okay first eventually wears out its welcome.                ',
#   0.7506,
#   'Positive'],
#  ['You me and Dupree',
#   'Thomas Delapa',
#   '                July 18, 2006            ',
#   "                    You Me Dupree doesn't risk failure so amounts nothing.                ",
#   0.5448,
#   'Positive'],
#  ['You me and Dupree',
#   'Scott Nash',
#   '                July 18, 2006            ',
#   "                    Russo Russo can't decide whether they're making sentimental farce about male friendship or raunchy comedy spiced up porn. latter wins out though audience  loser.                ",
#   0.6486,
#   'Positive'],
#  ['You me and Dupree',
#   'Betty Jo Tucker',
#   '                July 18, 2006            ',
#   "                    It only because Wilson's charm this movie manages entertain much it does which just barely enough.                ",
#   0.6124,
#   'Positive'],
#  ['You me and Dupree',
#   'Pete Vonder Haar',
#   '                July 17, 2006            ',
#   "                    Forget those awful previews. 'You Me Dupree' a rather sweet little movie focusing friendship love life goals  being true oneself.                ",
#   0.8288,
#   'Positive'],
#  ['You me and Dupree',
#   'Mike Ward',
#   '                July 17, 2006            ',
#   "                    Hectoring wife liking pretty boys sounds hollow coming from guy who launched thous Tiger Beats  late '70s early '80s.                ",
#   0.7506,
#   'Positive'],
#  ['You me and Dupree',
#   'Harvey S. Karten',
#   '                July 16, 2006            ',
#   "                    In year already underwhelmed us Failure Launch it's lot ask audiences take another raunchy comedy highlighting slacker lifestyle. (If we want watch truly skilled underachiever we'll watch Lebowski again)                ",
#   0.34,
#   'Positive'],
#  ['You me and Dupree',
#   'Fred Topel',
#   '                July 15, 2006            ',
#   "                    You've seen kind situation before but Owen Wilson gets warhorse new life.                ",
#   0.296,
#   'Positive'],
#  ['You me and Dupree',
#   'Sean McBride',
#   '                July 15, 2006            ',
#   " movie can't even decide who's doing what whom by end. Molly throws Carl out one point then comes back apologize walking out. That's because don't know how end movie unless someone apologizing something.                ",
#   0.0258,
#   'Neutral'],
#  ['You me and Dupree',
#   'Eric Lurio',
#   '                July 15, 2006            ',
#   "                    We've seen all before  quite frankly; starting get bit boring.                ",
#   -0.3182,
#   'Negative'],
#  ['You me and Dupree',
#   'Jason Zingale',
#   '                July 15, 2006            ',
#   "                    we get whole season's worth sitcom an less than two hours whether or not is good thing a quandary.                ",
#   -0.1295,
#   'Negative'],
#  ['You me and Dupree',
#   'Peter Howell',
#   '                July 15, 2006            ',
#   '                    None  characters fleshed out any way   whole married-men-are-eunuchs subtext just lazy.                ',
#   -0.3612,
#   'Negative'],
#  ['You me and Dupree',
#   'Stephanie Zacharek',
#   '                July 14, 2006            ',
#   '                    Owen Wilson perilously close doing Dupree his own career by wearing out welcome.                ',
#   0.4588,
#   'Positive'],
#  ['You me and Dupree',
#   'Gary Thompson',
#   '                July 14, 2006            ',
#   "                    You Me Dupree seems have been made by people who don't know difference between light comedy an inconsequential one.                ",
#   0.3612,
#   'Positive'],
#  ['You me and Dupree',
#   'Steven Rea',
#   '                July 14, 2006            ',
#   "                    In end Dupree doesn't add up much except forum Wilson's unique comic persona which more than enough fans.                ",
#   0.0,
#   'Neutral'],
#  ['You me and Dupree',
#   'Roger Moore',
#   '                July 14, 2006            ',
#   '                    Amiable if ragtag.                ',
#   0.0,
#   'Neutral']]

# %%
# Most repeated word Washington Post summary
sentence = ''
for i in reviews_big_bird:
    sentence = sentence + ' ' + i[3]

words = sentence.lower().split()
# Get the set of unique words.
from collections import Counter

# Pass the split_it list to instance of Counter class.
Counter = Counter(words)

# most_common() produces k frequently encountered
# input values and their respective counts.
most_occur = Counter.most_common(10)
print(most_occur)
# Out:
# [('a', 25), ('big', 22), ('am', 14), ('man', 14), ('spinney', 12), ('bird', 11), ('who', 10), ('story', 8), ('i', 7), ('not', 7)]

# %%
for i in reviews_big_bird:
    print(i[0] + ',' + i[1] + ',' + i[2] + ',' + i[3] + ',' + str(i[4]) + ',' + i[5])
# Out:
# I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS,Allen Almachar,                July 21, 2020            ,                    I Am Big Bird may not offer grandiose revelations ... it does provide glimpse into person who's touched more lives than some even aware of.                ,0.0,Neutral
# I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS,Brent McKnight,                July 5, 2020            ,                    It's impossible not walk away a smile your face.                ,0.3612,Positive
# I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS,Elissa Suh,                March 16, 2020            ,                    Who  man inside feathered suit? David LaMattina Chad N. Walker's straightforward documentary I Am Big Bird: Caroll Spinney Story explores just that giving face man behind bird since its inception.                ,0.34,Positive
# I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS,Daniel Barnes,                July 22, 2019            ,                    An open affecting look  little white-haired man inside  giant yellow suit.                ,0.0,Neutral
# I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS,Matthew Lucas,                July 5, 2019            ,                    truly magical experience from start finish with heart big kind  bird himself.                ,0.8885,Positive
# I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS,C.J. Prince,                June 20, 2019            , problem that LaMattina Walker refuse let Spinney's story brea for single moment instead relying a barrage maudlin tactics choke tears out viewers.                ,-0.8519,Negative
# I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS,Neely Swanson,                September 15, 2017            ,                    I Am Big Bird: Caroll Spinney Story"  delightful heartwarming story  man inside head  8 foot tall 6 year old who crossed borders transcended politics breached intractable boundaries enriched lives from inception.                ,0.7845,Positive
# I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS,Jonathan Kiefer,                August 24, 2017            ,                    slathering sentimentally triumphant music emphasizes what seems like feeling protectiveness their subject but fair enough.                ,0.7964,Positive
# I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS,Peter Calder,                May 16, 2016            ,                    It plays like extended promo washed a score elevator-music strings  composed so many talking-head snatches it often feels like trailer itself.                ,0.7184,Positive
# I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS,Norman Wilner,                December 18, 2015            ,                    It's amazing a documentary so clumsy such incredible highs lows but that's power Big Bird you.                ,0.217,Positive
# I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS,Beth Accomando,                November 9, 2015            ,                    I Am Big Bird not great filmmaking it pays fitting tribute Spinney  character into which invested so much his own personality.                ,-0.5096,Negative
# I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS,Leigh Paatsch,                July 31, 2015            , purity intent sophisticated craft [Spinney] poured into their creation remains unacknowledged by general public. modestly appointed crowd-funded documentary I Am Big Bird should clear up oversight once for all.                ,0.8074,Positive
# I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS,Jarrod Walker,                July 30, 2015            ,                    Spinney well-deserving  attention  from standpoint sheer curiosity fascination knowing more about man who created character we loved children that our children now love is gently poignant experience.                ,0.946,Positive
# I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS,Andrew L. Urban,                July 27, 2015            ,                    This adulatory doco Spinney's life work a handful love stories glued together by Spinney who at centre it. kinda This Your Life doco                ,0.6369,Positive
# I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS,Michael O'Sullivan,                June 25, 2015            ,                    There's little sour temper sweetness this portrait.                ,0.1065,Positive
# I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS,Frank Swietek,                June 19, 2015            ,                    While nice--arguably too nice in fact--it feels like fifty minutes material drawn out nearly ninety.                ,0.6486,Positive
# I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS,Moira MacDonald,                June 18, 2015            ,                    Though its gooey sentimental soundtrack a misstep - story quite sweet enough already - "I Am Big Bird" mesmerizing anyone ( that's lot us) who grew up "Sesame Street."                ,0.6801,Positive
# I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS,Dave McGinn,                May 29, 2015            ,                    Very much heartwarming tribute bordering treacly.                ,0.5233,Positive
# I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS,Jim Slotek,                May 28, 2015            ,                    Spinney a one-of-a-kind personality an oddball even among oddballs who pioneered Sesame Street's Children's Television Workshop.                ,0.0,Neutral
# I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS,Stephen Silver,                May 22, 2015            ,                    In less than 90 minutes it's reasonably complete history  big Bird character  man it.                ,0.0,Neutral
# I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS,James Rocchi,                May 22, 2015            ,                    Not definitive story Sesame Street but a superb portrait one its longest residents  a peek behind scenes well worth taking anyone who grew up one pop culture's most identifiable most long-lived children's icons.                ,0.8922,Positive
# I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS,Tony Macklin,                May 21, 2015            ,                    Children love underst  majestic galoot.                ,0.6369,Positive
# I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS,Blake Goble,                May 20, 2015            ,                    I Am Big Bird: Caroll Spinney Story for most part is puff piece. feather film if will. It's nice flavorful yellow a Nilla cookie.                ,0.4215,Positive
# I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS,Andrea Chase,                May 15, 2015            ,                    gentle sensitive film about gentle sensitive man.                ,0.7003,Positive
# I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS,Peter Rainer,                May 15, 2015            ,                    Affectionately saccharine.                ,0.4939,Positive
# I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS,Anita Katz,                May 15, 2015            ,                    Mushy times likable all over.                ,0.0,Neutral
# I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS,Nina Garin,                May 15, 2015            ,                    Yes there's lot information "I Am Big Bird " sometimes is bit self-serving. at heart a love story between Spinney that big yellow bird all us.                ,0.9022,Positive
# I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS,Marc Mohan,                May 15, 2015            ,                    With heyday "Sesame Street" undeniably  past "I Am Big Bird" will primarily appeal nostalgic grownups. as Spinney demonstrates you're never too old be kid heart.                ,0.6369,Positive
# I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS,Tom Long,                May 15, 2015            ,                    There's no ducking frank admiration love display "I Am Big Bird: Carroll Spinney Story." Then again there's lot love admire here. It's freaking Big Bird.                ,0.9001,Positive
# I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS,Mark Dujsik,                May 14, 2015            ,                    We get surface who man is but -- perhaps is testament  man himself -- we want know more.                ,0.1154,Positive
# I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS,Richard Roeper,                May 14, 2015            ,                    These sobering moments aside  great bulk "I Am Big Bird" a Sunny Day Sweepin' Clouds Away brightly colored tribute  man his art.                ,0.8225,Positive
# I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS,Betsy Sharkey,                May 14, 2015            , kind heartwarming sentimental tale a gentle soul  PBS show's iconic character would love.                ,0.9423,Positive
# I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS,J. R. Jones,                May 14, 2015            ,                    Behind-the-scenes footage provides some fascinating glimpses Sesame Street being blocked.                ,0.34,Positive
# I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS,Steven Rea,                May 14, 2015            ,                    Spinney comes across a man whose warm spirit literally  core  loving if loopy Big Bird.                ,0.7579,Positive
# I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS,Randy Cordova,                May 14, 2015            ,                    Befitting subject matter  movie sweet-natured sentimental.                ,0.34,Positive
# I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS,Walter V. Addiego,                May 14, 2015            ,                    celebration an artist who's utterly delighted international audience children - more than few adults.                ,0.5563,Positive
# I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS,Brian Orndorf,                May 14, 2015            ,                    Perhaps sharper exploration Spinney's life isn't presented but documentary gets by  basics supplying new perspective  puppeteer his legacy.                ,0.1154,Positive
# I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS,Sean Burns,                May 13, 2015            ,                    It impossible observe film's interviews Spinney not be taken aback by man's extraordinary sensitivity   deeply unhappy childhood seems still very much him today.                ,-0.4754,Negative
# I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS,Mike Scott,                May 12, 2015            ,                    Every bit warm kind-hearted  man whose story tells.                ,0.2263,Positive
# I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS,Ronnie Scheib,                May 11, 2015            ,                    Schmaltz continually threatens overcome genius this super-sentimental account gifted puppeteer Caroll Spinney.                ,-0.3818,Negative
# I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS,Sheila O'Malley,                May 8, 2015            ,                    "I Am Big Bird" a loving personal profile Spinney with memories anecdotes shared by wife his children his co-workers friends.                ,0.8555,Positive
# I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS,Laura Clifford,                May 7, 2015            ,                    Four years after "Being Elmo: Puppeteer's Journey" promoted idea a Muppet character embodied love along come documentarian duo Dave LaMattina Chad N. Walker reinstate legacy Sesame Street's original star.                ,0.8519,Positive
# I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS,Robin Clifford,                May 7, 2015            , main thing I got out "I Am Big Bird" this: Big Bird = unconditional love.                ,0.6369,Positive
# I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS,Linda Holmes,                May 7, 2015            ,                    For Muppet enthusiasts or just folks who like hear about unusual jobs it's worth seeking out.                ,0.7003,Positive
# I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS,Odie Henderson,                May 7, 2015            ,                    ...I Am Big Bird: Caroll Spinney Story a profoundly moving documentary.                ,0.0,Neutral
# I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS,Mike McGranaghan,                May 7, 2015            ,                    wonderful inspiring look how best art regardless  age group which aimed always comes a special personal touch makes indelible.                ,0.9246,Positive
# I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS,Jesse Hassenger,                May 7, 2015            ,                    Spinney's unassuming career worth celebrating even if doesn't provide much a story.                ,0.6808,Positive
# I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS,Mark Moring,                May 6, 2015            ,                    Charming fascinating.                ,0.8074,Positive
# I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS,Frank Scheck,                May 6, 2015            ,                    If there ever man lucky enough have found true calling life it's subject Dave LaMattina Chad N. Walker's affecting documentary.                ,0.6808,Positive
# I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS,Joe Neumaier,                May 6, 2015            ,                    You'll find few touching moments some iconic images Gen-X viewers but don't expect any feathers get ruffled.                ,0.0,Neutral
# I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS,Jen Chaney,                May 6, 2015            ,                    This a profile a decent man who permanently associated a revered pop-cultural icon.                ,0.5106,Positive
# I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS,David Noh,                May 6, 2015            , man lurking beneath all those Big Bird yellow feathers takes spotlight this highly endearing documentary.                ,-0.128,Negative
# I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS,Matt Prigge,                May 6, 2015            ,                    It gives  impression knowing him well  it does it amazingly while barely showing face.                ,0.4588,Positive
# I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS,Stephen Whitty,                May 6, 2015            ,                    We learn about highs lows Spinney's life  get some insight into character - character which not surprisingly seems have same capacity childlike wonder joy much-mourned Henson had.                ,0.276,Positive
# I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS,Neil Genzlinger,                May 5, 2015            , film gets little syrupy times but Mr. Spinney forthright engaging throughout.                ,0.4767,Positive
# I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS,Mark Kermode,                May 4, 2015            ,                    An incessantly schmaltzy TV score threatens drown us syrup but sight Big Bird singing It's Not Easy Being Green Jim Henson's memorial provides powerful emotional sucker-punch.                ,-0.1677,Negative
# I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS,Amber Wilkinson,                May 4, 2015            , overall effect drenched by Joshua Johnson's unnecessarily surging score is far too portentous its own good.                ,0.4404,Positive
# I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS,Chuck Bowen,                May 3, 2015            , transcendence  film offers isn't be taken lightly considering near impossibility living professionally an artist.                ,0.0,Neutral
# I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS,Adam Woodward,                May 1, 2015            ,                    One warm your cockles.                ,0.2263,Positive

# %%
import requests
# If you are using a Jupyter notebook, uncomment the following line.
# %matplotlib inline
import matplotlib.pyplot as plt
import json
from PIL import Image
from io import BytesIO

# Add your Computer Vision subscription key and endpoint to your environment variables.
if 'COMPUTER_VISION_SUBSCRIPTION_KEY' in os.environ:
    subscription_key = os.environ['COMPUTER_VISION_SUBSCRIPTION_KEY']
else:
    print("\nSet the COMPUTER_VISION_SUBSCRIPTION_KEY environment variable.\n**Restart your shell or IDE for changes to take effect.**")
    sys.exit()

if 'COMPUTER_VISION_ENDPOINT' in os.environ:
    endpoint = os.environ['COMPUTER_VISION_ENDPOINT']

analyze_url = endpoint + "vision/v3.1/analyze"

# Set image_url to the URL of an image that you want to analyze.
image_url = "https://upload.wikimedia.org/wikipedia/commons/thumb/1/12/" + \
    "Broadway_and_Times_Square_by_night.jpg/450px-Broadway_and_Times_Square_by_night.jpg"

headers = {'Ocp-Apim-Subscription-Key': subscription_key}
params = {'visualFeatures': 'Categories,Description,Color'}
data = {'url': image_url}
response = requests.post(analyze_url, headers=headers,
                         params=params, json=data)
response.raise_for_status()

# The 'analysis' object contains various fields that describe the image. The most
# relevant caption for the image is obtained from the 'description' property.
analysis = response.json()
print(json.dumps(response.json()))
image_caption = analysis["description"]["captions"][0]["text"].capitalize()

# Display the image and overlay it with the caption.
image = Image.open(BytesIO(requests.get(image_url).content))
plt.imshow(image)
plt.axis("off")
_ = plt.title(image_caption, size="x-large", y=-0.1)
plt.show()

# %%
from azure.cognitiveservices.vision.computervision import ComputerVisionClient
from azure.cognitiveservices.vision.computervision.models import OperationStatusCodes
from azure.cognitiveservices.vision.computervision.models import VisualFeatureTypes
from msrest.authentication import CognitiveServicesCredentials

from array import array
import os
from PIL import Image
import sys
import time

# %%
subscription_key = "bf0972842491432d92a8149cd45e9434"
endpoint = "https://finalassignment.cognitiveservices.azure.com/"

# %%
computervision_client = ComputerVisionClient(endpoint, CognitiveServicesCredentials(subscription_key))

# %%
remote_image_url = "https://raw.githubusercontent.com/Azure-Samples/cognitive-services-sample-data-files/master/ComputerVision/Images/landmark.jpg"

# %%
'''
Describe an Image - remote
This example describes the contents of an image with the confidence score.
'''
print("===== Describe an image - remote =====")
# Call API
description_results = computervision_client.describe_image(remote_image_url )

# Get the captions (descriptions) from the response, with confidence level
print("Description of remote image: ")
if (len(description_results.captions) == 0):
    print("No description detected.")
else:
    for caption in description_results.captions:
        print("'{}' with confidence {:.2f}%".format(caption.text, caption.confidence * 100))
# Out:
# ===== Describe an image - remote =====
# Description of remote image:
# 'a large stone structure with many arches with Colosseum in the background' with confidence 26.39%

# %%
'''
Categorize an Image - remote
This example extracts (general) categories from a remote image with a confidence score.
'''
print("===== Categorize an image - remote =====")
# Select the visual feature(s) you want.
remote_image_features = ["categories"]
# Call API with URL and features
categorize_results_remote = computervision_client.analyze_image(remote_image_url , remote_image_features)

# Print results with confidence score
print("Categories from remote image: ")
if (len(categorize_results_remote.categories) == 0):
    print("No categories detected.")
else:
    for category in categorize_results_remote.categories:
        print("'{}' with confidence {:.2f}%".format(category.name, category.score * 100))
# Out:
# ===== Categorize an image - remote =====
# Categories from remote image:
# 'building_' with confidence 31.64%
# 'others_' with confidence 0.39%
# 'outdoor_' with confidence 3.91%

# %%
'''
Tag an Image - remote
This example returns a tag (key word) for each thing in the image.
'''
print("===== Tag an image - remote =====")
# Call API with remote image
tags_result_remote = computervision_client.tag_image(remote_image_url )

# Print results with confidence score
print("Tags in the remote image: ")
if (len(tags_result_remote.tags) == 0):
    print("No tags detected.")
else:
    for tag in tags_result_remote.tags:
        print("'{}' with confidence {:.2f}%".format(tag.name, tag.confidence * 100))
# Out:
# ===== Tag an image - remote =====
# Tags in the remote image:
# 'building' with confidence 99.92%
# 'outdoor' with confidence 97.66%
# 'sky' with confidence 93.79%
# 'ruins' with confidence 76.13%
# 'amphitheatre' with confidence 56.34%

# %%
'''
Detect Faces - remote
This example detects faces in a remote image, gets their gender and age, 
and marks them with a bounding box.
'''
print("===== Detect Faces - remote =====")
# Get an image with faces
remote_image_url_faces = "https://raw.githubusercontent.com/Azure-Samples/cognitive-services-sample-data-files/master/ComputerVision/Images/faces.jpg"
# Select the visual feature(s) you want.
remote_image_features = ["faces"]
# Call the API with remote URL and features
detect_faces_results_remote = computervision_client.analyze_image(remote_image_url_faces, remote_image_features)

# Print the results with gender, age, and bounding box
print("Faces in the remote image: ")
if (len(detect_faces_results_remote.faces) == 0):
    print("No faces detected.")
else:
    for face in detect_faces_results_remote.faces:
        print("'{}' of age {} at location {}, {}, {}, {}".format(face.gender, face.age, \
        face.face_rectangle.left, face.face_rectangle.top, \
        face.face_rectangle.left + face.face_rectangle.width, \
        face.face_rectangle.top + face.face_rectangle.height))
# Out:
# ===== Detect Faces - remote =====
# Faces in the remote image:
# 'Male' of age 39 at location 118, 159, 212, 253
# 'Male' of age 54 at location 492, 111, 582, 201
# 'Female' of age 55 at location 18, 153, 102, 237
# 'Female' of age 33 at location 386, 166, 467, 247
# 'Female' of age 18 at location 235, 158, 311, 234
# 'Female' of age 8 at location 323, 163, 391, 231

# %%
'''
Detect Domain-specific Content - remote
This example detects celebrites and landmarks in remote images.
'''
print("===== Detect Domain-specific Content - remote =====")
# URL of one or more celebrities
remote_image_url_celebs = "https://raw.githubusercontent.com/Azure-Samples/cognitive-services-sample-data-files/master/ComputerVision/Images/faces.jpg"
# Call API with content type (celebrities) and URL
detect_domain_results_celebs_remote = computervision_client.analyze_image_by_domain("celebrities", remote_image_url_celebs)

# Print detection results with name
print("Celebrities in the remote image:")
if len(detect_domain_results_celebs_remote.result["celebrities"]) == 0:
    print("No celebrities detected.")
else:
    for celeb in detect_domain_results_celebs_remote.result["celebrities"]:
        print(celeb["name"])
# Out:
# ===== Detect Domain-specific Content - remote =====
# Celebrities in the remote image:
# Bern Collaco
