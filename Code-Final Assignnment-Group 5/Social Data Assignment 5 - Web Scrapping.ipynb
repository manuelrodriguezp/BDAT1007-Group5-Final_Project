# %%
# Web scrapping from reviews of movies from Rotten Tomatoes
# Movie: Hillbilly Elegy
# Import libraries
import requests
from bs4 import BeautifulSoup
import re

# Collect first page of artists’ list (Collecting and Parsing data)
page = requests.get('https://www.rottentomatoes.com/m/hillbilly_elegy/reviews?type=top_critics&sort=')

# Create a BeautifulSoup object
soup = BeautifulSoup(page.text, 'html.parser')

# Pull all text from the review 
hillbily_elegy = soup.find(class_='review_table')

# Remove tag <span>
for match in hillbily_elegy.findAll('span'):
    match.unwrap()

# Pull text from all instances of <h6> tag within BodyText div
hillbilly_review = hillbily_elegy.find_all(class_='the_review')

# Pull text from all instances of 'cast' tag within BodyText div
hillbilly_date = hillbily_elegy.find_all(class_='review-date subtle small')

# Pull text from all instances of 'genre' tag within BodyText div
hillbilly_critic = hillbily_elegy.find_all(class_='unstyled bold articleLink')

comments = []
for review in hillbilly_review:
    rev = review.contents[0]
    rev = re.sub('\r\n', '', rev)
    comments.append(rev)

dates = []
for date in hillbilly_date:
    dat = date.contents[0]
    dat = re.sub('\r\n', '', dat)
    dates.append(dat)

critics = []
for critic in hillbilly_critic:
    crit = critic.contents[0]
    crit = re.sub('\r\n', '', crit)
    critics.append(crit)

# Collect first page of artists’ list (Collecting and Parsing data)
page = requests.get('https://www.rottentomatoes.com/m/hillbilly_elegy/reviews?type=top_critics&sort=&page=2')

# Create a BeautifulSoup object
soup = BeautifulSoup(page.text, 'html.parser')

# Pull all text from the review 
hillbily_elegy = soup.find(class_='review_table')

# Remove tag <span>
for match in hillbily_elegy.findAll('span'):
    match.unwrap()

# Pull text from all instances of <h6> tag within BodyText div
hillbilly_review = hillbily_elegy.find_all(class_='the_review')

# Pull text from all instances of 'cast' tag within BodyText div
hillbilly_date = hillbily_elegy.find_all(class_='review-date subtle small')

# Pull text from all instances of 'genre' tag within BodyText div
hillbilly_critic = hillbily_elegy.find_all(class_='unstyled bold articleLink')

for review in hillbilly_review:
    rev = review.contents[0]
    rev = re.sub('\r\n', '', rev)
    comments.append(rev)

for date in hillbilly_date:
    dat = date.contents[0]
    dat = re.sub('\r\n', '', dat)
    dates.append(dat)

for critic in hillbilly_critic:
    crit = critic.contents[0]
    crit = re.sub('\r\n', '', crit)
    critics.append(crit)

# Collect first page of artists’ list (Collecting and Parsing data)
page = requests.get('https://www.rottentomatoes.com/m/hillbilly_elegy/reviews?type=top_critics&sort=&page=3')

# Create a BeautifulSoup object
soup = BeautifulSoup(page.text, 'html.parser')

# Pull all text from the review 
hillbily_elegy = soup.find(class_='review_table')

# Remove tag <span>
for match in hillbily_elegy.findAll('span'):
    match.unwrap()

# Pull text from all instances of <h6> tag within BodyText div
hillbilly_review = hillbily_elegy.find_all(class_='the_review')

# Pull text from all instances of 'cast' tag within BodyText div
hillbilly_date = hillbily_elegy.find_all(class_='review-date subtle small')

# Pull text from all instances of 'genre' tag within BodyText div
hillbilly_critic = hillbily_elegy.find_all(class_='unstyled bold articleLink')

for review in hillbilly_review:
    rev = review.contents[0]
    rev = re.sub('\r\n', '', rev)
    comments.append(rev)

for date in hillbilly_date:
    dat = date.contents[0]
    dat = re.sub('\r\n', '', dat)
    dates.append(dat)

for critic in hillbilly_critic:
    crit = critic.contents[0]
    crit = re.sub('\r\n', '', crit)
    critics.append(crit)

reviews_hillbilly_elegy = []
for i in range (0,57):
    record = []
    record.append('Hillbilly Elegy')
    record.append(critics[i])
    record.append(dates[i])
    record.append(comments[i])
    reviews_hillbilly_elegy.append(record)
reviews_hillbilly_elegy
# Out:
# [['Hillbilly Elegy',
#   'Sara Stewart',
#   '                December 4, 2020            ',
#   "                    There's only a vague message about bootstraps and personal responsibility, and a whole lot of bad wigs.                "],
#  ['Hillbilly Elegy',
#   'Jordan Hoffman',
#   '                December 4, 2020            ',
#   '                    Hillbilly Elegy and its Oscar dreams are all sizzle, no steak.                '],
#  ['Hillbilly Elegy',
#   'David Sims',
#   '                December 4, 2020            ',
#   '                    Hillbilly Elegy is an Oscar-friendly narrative of personal triumph in the face of great hardship, a movie designed to end with an uplifting epigraph; it is also one of the worst movies of the year.                '],
#  ['Hillbilly Elegy',
#   'Adam Nayman',
#   '                December 2, 2020            ',
# ...

# %%
# Web scrapping from reviews of movies from Rotten Tomatoes
# Movie: Bourne Identity
# Import libraries
import requests
from bs4 import BeautifulSoup

# Collect first page of artists’ list (Collecting and Parsing data)
page = requests.get('https://www.rottentomatoes.com/m/bourne_identity/reviews')

# Create a BeautifulSoup object
soup = BeautifulSoup(page.text, 'html.parser')

# Pull all text from the review 
Bourne_identity = soup.find(class_='review_table')

# Remove tag <span>
for match in Bourne_identity.findAll('span'):
    match.unwrap()

# Pull text from all instances of <h6> tag within BodyText div
bourne_review = Bourne_identity.find_all(class_='the_review')

# Pull text from all instances of 'cast' tag within BodyText div
bourne_date = Bourne_identity.find_all(class_='review-date subtle small')

# Pull text from all instances of 'genre' tag within BodyText div
bourne_critic = Bourne_identity.find_all(class_='unstyled bold articleLink')

comments = []
for review in bourne_review:
    rev = review.contents[0]
    rev = re.sub('\r\n', '', rev)
    comments.append(rev)

dates = []
for date in bourne_date:
    dat = date.contents[0]
    dat = re.sub('\r\n', '', dat)
    dates.append(dat)

critics = []
for critic in bourne_critic:
    crit = critic.contents[0]
    crit = re.sub('\r\n', '', crit)
    critics.append(crit)

# Collect first page of artists’ list (Collecting and Parsing data)
page = requests.get('https://www.rottentomatoes.com/m/bourne_identity/reviews?type=&sort=&page=2')

# Create a BeautifulSoup object
soup = BeautifulSoup(page.text, 'html.parser')

# Pull all text from the review 
Bourne_identity = soup.find(class_='review_table')

# Remove tag <span>
for match in Bourne_identity.findAll('span'):
    match.unwrap()

# Pull text from all instances of <h6> tag within BodyText div
bourne_review = Bourne_identity.find_all(class_='the_review')

# Pull text from all instances of 'cast' tag within BodyText div
bourne_date = Bourne_identity.find_all(class_='review-date subtle small')

# Pull text from all instances of 'genre' tag within BodyText div
bourne_critic = Bourne_identity.find_all(class_='unstyled bold articleLink')

for review in bourne_review:
    rev = review.contents[0]
    rev = re.sub('\r\n', '', rev)
    comments.append(rev)

for date in bourne_date:
    dat = date.contents[0]
    dat = re.sub('\r\n', '', dat)
    dates.append(dat)

for critic in bourne_critic:
    crit = critic.contents[0]
    crit = re.sub('\r\n', '', crit)
    critics.append(crit)

# Collect first page of artists’ list (Collecting and Parsing data)
page = requests.get('https://www.rottentomatoes.com/m/bourne_identity/reviews?type=&sort=&page=3')

# Create a BeautifulSoup object
soup = BeautifulSoup(page.text, 'html.parser')

# Pull all text from the review 
Bourne_identity = soup.find(class_='review_table')

# Remove tag <span>
for match in Bourne_identity.findAll('span'):
    match.unwrap()

# Pull text from all instances of <h6> tag within BodyText div
bourne_review = Bourne_identity.find_all(class_='the_review')

# Pull text from all instances of 'cast' tag within BodyText div
bourne_date = Bourne_identity.find_all(class_='review-date subtle small')

# Pull text from all instances of 'genre' tag within BodyText div
bourne_critic = Bourne_identity.find_all(class_='unstyled bold articleLink')

for review in bourne_review:
    rev = review.contents[0]
    rev = re.sub('\r\n', '', rev)
    comments.append(rev)

for date in bourne_date:
    dat = date.contents[0]
    dat = re.sub('\r\n', '', dat)
    dates.append(dat)

for critic in bourne_critic:
    crit = critic.contents[0]
    crit = re.sub('\r\n', '', crit)
    critics.append(crit)

reviews_bourne_identity = []
for i in range (0,59):
    record = []
    record.append('Bourne Identity')
    record.append(critics[i])
    record.append(dates[i])
    record.append(comments[i])
    reviews_bourne_identity.append(record)
    
reviews_bourne_identity
# Out:
# [['Bourne Identity',
#   'Film Companion Staff',
#   '                October 27, 2020            ',
#   "                    One man's heart-pounding crusade to tear down the crooked system that created him...                "],
#  ['Bourne Identity',
#   'Mike Massie',
#   '                September 29, 2020            ',
#   '                    Although the basic amnesia plot sets up a potential for excitement, the editing immediately becomes the most detrimental component in the action-packed world of Jason Bourne.                '],
#  ['Bourne Identity',
#   'Leigh Paatsch',
#   '                April 30, 2020            ',
#   '                    The franchise took a marked upturn in later instalments, but a fair first entry nonetheless.                '],
#  ['Bourne Identity',
#   'Namrata Joshi',
#   '                January 3, 2019            ',
# ...

# %%
# Web scrapping from reviews of movies from Rotten Tomatoes
# Movie: I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS
# Import libraries
import requests
from bs4 import BeautifulSoup

# Collect first page of artists’ list (Collecting and Parsing data)
page = requests.get('https://www.rottentomatoes.com/m/i_am_big_bird_the_caroll_spinney_story/reviews')

# Create a BeautifulSoup object
soup = BeautifulSoup(page.text, 'html.parser')

# Pull all text from the review 
big_bird = soup.find(class_='review_table')

# Remove tag <span>
for match in big_bird.findAll('span'):
    match.unwrap()

# Pull text from all instances of <h6> tag within BodyText div
bird_review = big_bird.find_all(class_='the_review')

# Pull text from all instances of 'cast' tag within BodyText div
bird_date = big_bird.find_all(class_='review-date subtle small')

# Pull text from all instances of 'genre' tag within BodyText div
bird_critic = big_bird.find_all(class_='unstyled bold articleLink')

comments = []
for review in bird_review:
    rev = review.contents[0]
    rev = re.sub('\r\n', '', rev)
    comments.append(rev)

dates = []
for date in bird_date:
    dat = date.contents[0]
    dat = re.sub('\r\n', '', dat)
    dates.append(dat)

critics = []
for critic in bird_critic:
    crit = critic.contents[0]
    crit = re.sub('\r\n', '', crit)
    critics.append(crit)

# Collect first page of artists’ list (Collecting and Parsing data)
page = requests.get('https://www.rottentomatoes.com/m/i_am_big_bird_the_caroll_spinney_story/reviews?type=&sort=&page=2')

# Create a BeautifulSoup object
soup = BeautifulSoup(page.text, 'html.parser')

# Pull all text from the review 
big_bird = soup.find(class_='review_table')

# Remove tag <span>
for match in big_bird.findAll('span'):
    match.unwrap()

# Pull text from all instances of <h6> tag within BodyText div
bird_review = big_bird.find_all(class_='the_review')

# Pull text from all instances of 'cast' tag within BodyText div
bird_date = big_bird.find_all(class_='review-date subtle small')

# Pull text from all instances of 'genre' tag within BodyText div
bird_critic = big_bird.find_all(class_='unstyled bold articleLink')

for review in bird_review:
    rev = review.contents[0]
    rev = re.sub('\r\n', '', rev)
    comments.append(rev)

for date in bird_date:
    dat = date.contents[0]
    dat = re.sub('\r\n', '', dat)
    dates.append(dat)

for critic in bird_critic:
    crit = critic.contents[0]
    crit = re.sub('\r\n', '', crit)
    critics.append(crit)
    
# Collect first page of artists’ list (Collecting and Parsing data)
page = requests.get('https://www.rottentomatoes.com/m/i_am_big_bird_the_caroll_spinney_story/reviews?type=&sort=&page=3')

# Create a BeautifulSoup object
soup = BeautifulSoup(page.text, 'html.parser')

# Pull all text from the review 
big_bird = soup.find(class_='review_table')

# Remove tag <span>
for match in big_bird.findAll('span'):
    match.unwrap()

# Pull text from all instances of <h6> tag within BodyText div
bird_review = big_bird.find_all(class_='the_review')

# Pull text from all instances of 'cast' tag within BodyText div
bird_date = big_bird.find_all(class_='review-date subtle small')

# Pull text from all instances of 'genre' tag within BodyText div
bird_critic = big_bird.find_all(class_='unstyled bold articleLink')

for review in bird_review:
    rev = review.contents[0]
    rev = re.sub('\r\n', '', rev)
    comments.append(rev)

for date in bird_date:
    dat = date.contents[0]
    dat = re.sub('\r\n', '', dat)
    dates.append(dat)

for critic in bird_critic:
    crit = critic.contents[0]
    crit = re.sub('\r\n', '', crit)
    critics.append(crit)
    
reviews_big_bird = []
for i in range (0,59):
    record = []
    record.append('I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS')
    record.append(critics[i])
    record.append(dates[i])
    record.append(comments[i])
    reviews_big_bird.append(record)
    
reviews_big_bird
# Out:
# [['I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS',
#   'Allen Almachar',
#   '                July 21, 2020            ',
#   "                    I Am Big Bird may not offer grandiose revelations ... but it does provide a glimpse into a person who's touched more lives than some are even aware of.                "],
#  ['I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS',
#   'Brent McKnight',
#   '                July 5, 2020            ',
#   "                    It's impossible not to walk away with a smile on your face.                "],
#  ['I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS',
#   'Elissa Suh',
#   '                March 16, 2020            ',
#   "                    Who is the man inside the feathered suit? David LaMattina and Chad N. Walker's straightforward documentary I Am Big Bird: The Caroll Spinney Story explores just that, giving a face to man behind the bird since its inception.                "],
#  ['I AM BIG BIRD: THE CAROLL SPINNEY STORY REVIEWS',
# ...

# %%
# Web scrapping from reviews of movies from Rotten Tomatoes
# Movie: You, me and Dupree
# Import libraries
import requests
from bs4 import BeautifulSoup

# Collect first page of artists’ list (Collecting and Parsing data)
page = requests.get('https://www.rottentomatoes.com/m/you_me_and_dupree/reviews')

# Create a BeautifulSoup object
soup = BeautifulSoup(page.text, 'html.parser')

# Pull all text from the review 
dupree = soup.find(class_='review_table')

# Remove tag <span>
for match in big_bird.findAll('span'):
    match.unwrap()

# Pull text from all instances of <h6> tag within BodyText div
dupree_review = dupree.find_all(class_='the_review')

# Pull text from all instances of 'cast' tag within BodyText div
dupree_date = dupree.find_all(class_='review-date subtle small')

# Pull text from all instances of 'genre' tag within BodyText div
dupree_critic = dupree.find_all(class_='unstyled bold articleLink')

comments = []
for review in dupree_review:
    rev = review.contents[0]
    rev = re.sub('\r\n', '', rev)
    comments.append(rev)

dates = []
for date in dupree_date:
    dat = date.contents[0]
    dat = re.sub('\r\n', '', dat)
    dates.append(dat)

critics = []
for critic in dupree_critic:
    crit = critic.contents[0]
    crit = re.sub('\r\n', '', crit)
    critics.append(crit)

# Collect first page of artists’ list (Collecting and Parsing data)
page = requests.get('https://www.rottentomatoes.com/m/you_me_and_dupree/reviews?type=&sort=&page=2')

# Create a BeautifulSoup object
soup = BeautifulSoup(page.text, 'html.parser')

# Pull all text from the review 
dupree = soup.find(class_='review_table')

# Remove tag <span>
for match in big_bird.findAll('span'):
    match.unwrap()

# Pull text from all instances of <h6> tag within BodyText div
dupree_review = dupree.find_all(class_='the_review')

# Pull text from all instances of 'cast' tag within BodyText div
dupree_date = dupree.find_all(class_='review-date subtle small')

# Pull text from all instances of 'genre' tag within BodyText div
dupree_critic = dupree.find_all(class_='unstyled bold articleLink')

for review in dupree_review:
    rev = review.contents[0]
    rev = re.sub('\r\n', '', rev)
    comments.append(rev)

for date in dupree_date:
    dat = date.contents[0]
    dat = re.sub('\r\n', '', dat)
    dates.append(dat)

for critic in dupree_critic:
    crit = critic.contents[0]
    crit = re.sub('\r\n', '', crit)
    critics.append(crit)
    
# Collect first page of artists’ list (Collecting and Parsing data)
page = requests.get('https://www.rottentomatoes.com/m/you_me_and_dupree/reviews?type=&sort=&page=3')

# Create a BeautifulSoup object
soup = BeautifulSoup(page.text, 'html.parser')

# Pull all text from the review 
dupree = soup.find(class_='review_table')

# Remove tag <span>
for match in big_bird.findAll('span'):
    match.unwrap()

# Pull text from all instances of <h6> tag within BodyText div
dupree_review = dupree.find_all(class_='the_review')

# Pull text from all instances of 'cast' tag within BodyText div
dupree_date = dupree.find_all(class_='review-date subtle small')

# Pull text from all instances of 'genre' tag within BodyText div
dupree_critic = dupree.find_all(class_='unstyled bold articleLink')

for review in dupree_review:
    rev = review.contents[0]
    rev = re.sub('\r\n', '', rev)
    comments.append(rev)

for date in dupree_date:
    dat = date.contents[0]
    dat = re.sub('\r\n', '', dat)
    dates.append(dat)

for critic in dupree_critic:
    crit = critic.contents[0]
    crit = re.sub('\r\n', '', crit)
    critics.append(crit)

reviews_dupree = []
for i in range (0,59):
    record = []
    record.append('You, me and Dupree')
    record.append(critics[i])
    record.append(dates[i])
    record.append(comments[i])
    reviews_dupree.append(record)
    
reviews_dupree
# Out:
# [['You, me and Dupree',
#   'Richard Propes',
#   '                September 27, 2020            ',
#   "                    Hudson isn't quite able to carry the film alone.                "],
#  ['You, me and Dupree',
#   'Leah Rozen',
#   '                April 22, 2020            ',
#   "                    You, Me and Dupree is a slight, meandering comedy that, much like Dupree on his wobbly bicycle, spins its wheels but doesn't get far.                "],
#  ['You, me and Dupree',
#   'Ali Gray',
#   '                April 22, 2020            ',
#   "                    You, Me And Dupree is a film that is almost instantly forgettable. Even now, a few hours after watching it, I'm struggling to remember character names...                "],
#  ['You, me and Dupree',
#   'John Ferguson',
#   '                April 22, 2020            ',
#   "                    Owen Wilson's laid-back slacker charm isn't enough to carry this flimsy, contrived comedy vehicle...                "],
# ...
